# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)

# %%
import os
import numpy as np
from sklearn.metrics import f1_score
from transformers import XLMRobertaTokenizerFast, XLMRobertaForTokenClassification, TrainingArguments, Trainer

tokenizer = XLMRobertaTokenizerFast.from_pretrained("xlm-roberta-base")
model = XLMRobertaForTokenClassification.from_pretrained("xlm-roberta-base")
# Out:
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForTokenClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
# replace __MACOSX/._test_data? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_data/113534_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace __MACOSX/test_data/._113534_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_data/547532_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace __MACOSX/test_data/._547532_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_data/204220_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace __MACOSX/test_data/._204220_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_data/185911_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace __MACOSX/test_data/._185911_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_data/194112_text.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import os
import re
# collect data

def create_dataset(txt_file, ann_file):
    with open(txt_file, "r") as txt_f, open(ann_file, "r") as ann_f:
        fulltext = re.sub('\xa0', ' ', txt_f.read())
        annotations = ann_f.readlines()
        
        sentences = [x for x in filter(None, fulltext.split('\n'))]
        labels = [list() for _ in sentences]
        for line in annotations:
            if line.startswith("T"):
                _, entity_type, start, end, *text = line.split()
                try:
                    start = int(start)
                    end = int(end)
                except Exception as e:
                    break
                for i, curr_sent in enumerate(sentences):
                    esc_text = re.escape(curr_sent)
                    for curr_sent_span in re.finditer(esc_text+'\n', fulltext):
                        curr_sent_span = curr_sent_span.span()
                        if end <= curr_sent_span[1]:
                            try:
                                labels[i].append((re.search(re.escape(" ".join(text)), curr_sent).span()[0],
                                                 re.search(re.escape(" ".join(text)), curr_sent).span()[1],
                                                 entity_type))
#                                 print(text,
#                                       re.search(re.escape(" ".join(text)), curr_sent).span()[0],
#                                       re.search(re.escape(" ".join(text)), curr_sent).span()[1],
#                                       entity_type)
                            except Exception as e:
                                continue
                            break
    return sentences, labels

X_data = []
y_data = []
numberoffiles = 0

for subdir, dirs, files in os.walk('/content/train_data'):
    for file in files:
        if file.endswith(".txt"):
            txt_file = os.path.join(subdir, file)
#             print(txt_file)
            filetext = open(txt_file, 'r').read()
            ann_file = os.path.join(txt_file[:-4] + ".ann")
            if os.path.isfile(ann_file):
                numberoffiles += 1
                X, y = create_dataset(txt_file, ann_file)
                X_data.extend(X)
                y_data.extend(y)

# %%
assert len(y_data) == len(X_data)
len(y_data)
# Out:
# 7976

# %%
X_data, y_data
# Out:
# (['Марк Цукерберг стал Человеком года',
#   'Журнал Time назвал Марка Цукерберга, основателя социальной сети Facebook с более чем половиной миллиарда пользователей по всему миру, Человеком года. По мнению редакции Time, в течение 2010 года Цукерберг существенным образом изменил жизнь миллионов людей и оказал огромное влияние на события, происходящие в мире. «Это не просто новая технология. Это социальная инженерия. Это меняет то, каким образом мы общаемся друг с другом. Я действительно думаю, что это влияет на человеческую природу так, как ещё никогда до этого», — сказал в эфире телеканала NBC главный редактор Time Ричард Стенгел.',
#   '26-летний Цукерберг стал самым молодым победителем в этой номинации в истории — с тех пор, как в 1927 году первым Человеком года был назван пилот Чарльз Линдберг, в одиночку перелетевший Атлантический океан.',
#   'Впрочем, решение относительно Цукерберга далось Time с большим трудом: победителем читательского голосования на сайте журнала стал основатель WikiLeaks Джулиан Ассанж, однако итоговое решение редакции оказалось не в его пользу. Надо думать, по политическим соображениям.',
#   'Вернисаж  прошёл без особого пафоса, но присутствовали на нём не только представители СМИ, фотографы и просто любители живописи, но и «коллеги по цеху», галеристы.',
#   'В церемонии открытия участвовали: директор Художественного музея Пётр Хрисанов; Борис Салахов, государственный эксперт по культурным ценностям, заведующий выставочным отделом; Екатерина Хотинова, старший научный сотрудник сочинского Художественного музея.',
#   'После официальной части все поднялись на третий этаж музея, где в самом большом зале расположена экспозиция.',
#   'Кирилл Бородин сказал:',
#   'Для самого насыщенного яркими красками и витаминами города страны я подготовил выставку «Витамин Б». В экспозицию включены несколько живописных серий — можно будет увидеть часть работ из моего 4 месячного пленэра в Таиланде 2013 года, картины проекта «Китайское детство», которые я представлял на Уральской Биеннале современного искусства, анималистические работы и многие другие.',
#   'И действительно, представленные работы художника наполнили пространство зала настоящими витаминами жизнелюбия, юмора вперемежку с иронией, они буквально искрят озорством и позитивом.',
#   'Любой желающий мог пообщаться и сфотографироваться с художником, получить ответы на интересующие вопросы.',
#   'Вход на вернисаж был свободным, ну а сама выставка будет длиться до 15 января.',
#   'Суд Милана приговорил Сильвио Берлускони к четырём годам тюрьмы',
#   'Сильвио Берлускони.',
#   'Владимир Путин и Сильвио Берлускони.',
#   '26 октября 2012 года суд Милана признал бывшего премьера Италии Сильвио Берлускони виновным в схемах по уклонению от уплаты налогов и приговорил его к четырём годам тюрьмы.',
#   'Кроме того, ему в течение трёх лет запрещено занимать государственные должности.',
#   'Бывший премьер Италии обвиняется в том, что в 1990-е годы неоднократно применял для ухода от уплаты налогов финансовую схему с использованием офшорной компании.',
#   'Так в 1994—1999 годах принадлежащая Берлускони компания Fininvest через посредников в офшорных зонах выкупила за 470 млн евро права на показ американских ТВ-каналов и фильмов и передала их дочерней компании Mediaset.',
#   'По мнению прокуратуры конечная цена была завышена для уменьшения налогооблагаемой базы в Италии, причём разница оседала в оффшорных фондах связанных с Берлускони.',
#   'Прокуратура требовала для бывшего главы государства наказания в виде лишения свободы на 3 года и 8 месяцев.',
#   'Однако суд назначил наказание выше требуемого.',
#   'Через несколько часов после первых сообщений ленты новостных агентств облетело следующее срочное сообщение.',
#   'В соответствии с принятой левоцентристским правительством Романо Проди в 2006 году амнистией, принятой с целью обезопасить тюрьмы от переполнения, срок Сильвио Берлускони может быть сокращён до одного года.',
#   'Адвокаты предпринимателя пока не комментируют решение суда.',
#   'Интересно, что вчера 76-летний бывший премьер-министр Италии и лидер главной партии правого центра «Народ свободы» окончательно объявил о своем уходе с политической арены.',
#   'В частности он заявил:',
#   ' Из любви к Италии можно совершать безумства и делать мудрые вещи 19 лет назад я начал политическую карьеру Это было безумством не лишенным мудрости Сейчас предпочитаю сделать шаг назад по тем же причинам и соображениям которые двигали мной в 1994 году Но у меня еще есть мускулы и мысли и я готов давать советы делиться опытом ',
#   'Первым вице-президентом Кубы избран 53-летний экс-министр образования Мигель Диас-Канель Бермудес, которого называют наиболее вероятным преемником Рауль Кастро.',
#   'Первым вице-президентом избран Мигель Диас-Канель Бермудес (Miguel Mario Díaz-Canel Bermúdez).',
#   'Рауль Кастро заявил, что уйдет в отставку после окончания срока своих полномочий в 2018 году.',
#   'Национальная ассамблея избрала 31 члена Госсовета, назначив Кастро его председателем.',
#   'Ожидается, что новый пятилетний срок станет для 81-летнего политика последним, и Кастро больше не будет выдвигать свою кандидатуру на пост руководителя.',
#   'Позднее Рауль Кастро подтвердил информацию о том, что намерен оставить политику по окончании срока в 2018 года.',
#   'Глава Кубы объявил об этом в своем выступлении в воскресенье, вскоре после того как Национальная ассамблея Кубы в Гаване избрала его на эту должность на новый пятилетний срок.',
#   'Председатель Государственного совета Кубы — высшая государственная должность в Республике Куба, установленная после Революции 1959 года.',
#   'Председатель имеет политическую, законодательную и судебную власть.',
#   'Является Председателем совета министров, и верховным главнокомандующим.',
#   'Новым спикером был назначен 69-летний экономист Эстебан Ласо (Esteban Lazo Hernández).',
#   'Парламентарий входит в состав политбюро центрального комитета Коммунистической партии Кубы.',
#   'Рауль Кастро, который в 2008 году сменил на посту главы государства своего больного брата Фиделя, ранее предлагал ограничить срок полномочий членов руководства Компартии и правительства двумя пятилетними сроками.',
#   'За свои первые пять лет в качестве главы государства Кастро провел ограниченные реформы, которые, в частности, касались постепенных снятий ограничений на свободу передвижения и расширение прав на личное имущество граждан.',
#   'Бывший лидер Фидель Кастро преподнес сюрприз, появившись на открытии сессии Национальной ассамблеи.',
#   'В последние годы он появляется на публике крайне редко.',
#   'Члены парламенты встретили его бурными аплодисментами.',
#   'Победителем US Open впервые с 1936 года стал британец',
#   'Энди Маррей стал победителем Открытого чемпионата США по теннису (U.S. Open). Впервые с 1936 года титул турнира из серии «Большого шлема» достался британскому спортсмену.',
#   'Посеянный под третьим номером Маррей одержал победу над действующим чемпионом — сербским теннисистом Новаком Джоковичем, посеянным под вторым номером. Счёт в матче, продолжавшемся почти пять часов, составил 7:6, 7:5, 2:6, 3:6, 6:2.',
#   'Ранее 25-летний Маррей четыре раза выходил в финал турниров «Большого шлема», но каждый раз проигрывал.',
#   'После матча, похвалив своего соперника, он сказал: «Я не знаю, как мне это удалось».',
#   'В августе Маррей завоевал золотую медаль на Олимпиаде в Лондоне.',
#   'Станцию метро «Войковская» предложили переименовать в «Волковскую»',
#   'thumb|Станция метро «Войковская»',
#   'Самый дешёвый вариант переименования станции московского метро «Войковская», носящей имя цареубийцы Войкова, предложили москвичи: назвать её «Волковской», в честь Владислава Николаевича Волкова — одного из немногих москвичей в отряде космонавтов. При переименовании нужно будет всего лишь заменить букву «й» на букву «л».',
#   'Будущий космонавт Волков родился в районе станции метро «Войковская», закончил школу № 212 в Коптеве, а затем Московский авиационный институт, что в десяти минутах ходьбы от станции метро. Вблизи станции метро «Войковская» есть улица Космонавта Волкова, а также стоит памятник герою.',
#   'В 2008 году он проходил по делу о незаконном скачивании миллионов документов с серверов федеральной судебной системы. Тогда никаких обвинений ему предъявлено не было.',
#   'В июле 2011 года против Шварца было возбуждено судебное преследование за скачивание 4-х миллионов документов из онлайн-библиотеки JSTOR и размещение их в свободном доступе.',
#   'JSTOR отказалась от претензий к Шварцу, но прокуратура приняла решение продолжить дело, по которому ему грозило до 35-ти лет тюремного заключения.',
#   'Сам программист свою вину не признал.',
#   'По этому эпизоду суд не успел вынести приговор.',
#   'Последний раз Шварц публично обсуждал желание расстаться с жизнью в 2007 году, когда испытывал депрессию после продажи Reddit.',
#   'Что сейчас толкнуло его на этот шаг — неизвестно.',
#   'Аарон Шварц участвовал в Википедии под ником AaronSw.',
#   'После получения известия о смерти Аарона коллеги выразили соболезнования на его странице обсуждения (архивировано).',
# ...
#    (4, 7, 'PROFESSION'),
#    (15, 26, 'PERSON'),
#    (147, 160, 'CITY'),
#    (20, 26, 'PERSON'),
#    (205, 209, 'ORGANIZATION'),
#    (226, 236, 'AGE'),
#    (8, 14, 'CITY'),
#    (4, 14, 'PROFESSION'),
#    (111, 140, 'ORGANIZATION')],
#   [],
#   [(13, 16, 'PROFESSION'),
#    (282, 288, 'PERSON'),
#    (13, 16, 'PROFESSION'),
#    (183, 191, 'NUMBER'),
#    (282, 288, 'PERSON')],
#   [(161, 167, 'PERSON'),
#    (161, 167, 'PERSON'),
#    (7, 14, 'ORGANIZATION'),
#    (40, 46, 'COUNTRY'),
#    (161, 167, 'PERSON')],
#   [(282, 288, 'PERSON'),
#    (282, 288, 'PERSON'),
#    (282, 288, 'PERSON'),
#    (58, 81, 'STATE_OR_PROVINCE'),
#    (83, 97, 'NUMBER'),
#    (58, 81, 'STATE_OR_PROVINCE'),
#    (263, 270, 'CITY'),
#    (282, 288, 'PERSON')],
#   [(20, 24, 'COUNTRY'),
#    (55, 66, 'PERSON'),
#    (10, 17, 'EVENT'),
#    (10, 24, 'EVENT'),
#    (45, 54, 'PROFESSION')],
#   [(14, 20, 'LOCATION'), (0, 4, 'COUNTRY')],
#   [(32, 36, 'COUNTRY'),
#    (130, 141, 'PERSON'),
#    (0, 29, 'DATE'),
#    (32, 36, 'COUNTRY'),
#    (44, 64, 'EVENT'),
#    (120, 129, 'AGE'),
#    (130, 141, 'PERSON'),
#    (153, 159, 'PERCENT'),
#    (58, 64, 'EVENT'),
#    (44, 53, 'PROFESSION'),
#    (44, 57, 'PROFESSION'),
#    (44, 53, 'PROFESSION'),
#    (103, 119, 'PROFESSION')],
#   [(35, 49, 'ORGANIZATION'),
#    (51, 60, 'AGE'),
#    (61, 76, 'PERSON'),
#    (88, 94, 'PERCENT'),
#    (13, 26, 'IDEOLOGY')],
#   [(27, 38, 'PERSON'),
#    (27, 38, 'PERSON'),
#    (27, 38, 'PERSON'),
#    (68, 84, 'DATE'),
#    (111, 127, 'ORDINAL'),
#    (142, 158, 'PERSON'),
#    (12, 21, 'PROFESSION'),
#    (12, 21, 'PROFESSION'),
#    (7, 26, 'PROFESSION'),
#    (7, 21, 'PROFESSION'),
#    (50, 67, 'PROFESSION'),
#    (122, 139, 'PROFESSION'),
#    (22, 26, 'COUNTRY'),
#    (101, 110, 'EVENT')],
#   [(30, 36, 'EVENT'), (30, 36, 'EVENT')],
#   [(8, 18, 'PROFESSION'),
#    (37, 43, 'NUMBER'),
#    (8, 23, 'PROFESSION'),
#    (19, 23, 'COUNTRY'),
#    (19, 23, 'COUNTRY')],
#   [(35, 42, 'PERSON'),
#    (45, 55, 'PERSON'),
#    (101, 110, 'DATE'),
#    (119, 123, 'PERSON'),
#    (133, 154, 'PERCENT'),
#    (93, 100, 'EVENT'),
#    (93, 110, 'EVENT'),
#    (93, 100, 'EVENT')],
#   [(5, 11, 'EVENT'), (5, 11, 'EVENT')],
#   [(93, 98, 'CITY'),
#    (86, 90, 'COUNTRY'),
#    (86, 90, 'COUNTRY'),
#    (14, 23, 'IDEOLOGY'),
#    (35, 49, 'CRIME'),
#    (86, 90, 'COUNTRY')],
#   [(8, 15, 'ORGANIZATION'), (46, 67, 'EVENT'), (16, 41, 'EVENT')],
#   [(31, 36, 'CITY'), (31, 36, 'CITY')],
#   [(23, 30, 'EVENT'), (23, 30, 'EVENT'), (23, 30, 'EVENT')],
#   [(23, 34, 'EVENT')],
#   [(13, 23, 'CITY'), (24, 45, 'EVENT')],
#   [(40, 45, 'PRODUCT'), (0, 8, 'EVENT'), (43, 45, 'NUMBER')],
#   [(27, 37, 'CITY'),
#    (13, 26, 'COUNTRY'),
#    (27, 37, 'CITY'),
#    (52, 61, 'DATE'),
#    (92, 100, 'NUMBER'),
#    (62, 79, 'EVENT'),
#    (81, 129, 'EVENT')],
#   [],
#   [(6, 15, 'DATE'),
#    (0, 15, 'TIME'),
#    (6, 15, 'DATE'),
#    (18, 28, 'CITY'),
#    (39, 52, 'PERSON'),
#    (155, 157, 'NUMBER'),
#    (167, 176, 'NUMBER'),
#    (53, 77, 'EVENT'),
#    (29, 38, 'AGE'),
#    (148, 165, 'EVENT')],
#   [(81, 83, 'ORDINAL'),
#    (93, 99, 'PERSON'),
#    (22, 41, 'PROFESSION'),
#    (100, 111, 'EVENT')],
#   [(19, 21, 'NUMBER'), (40, 44, 'NUMBER'), (13, 36, 'EVENT')],
#   [(0, 6, 'PERSON'), (0, 6, 'PERSON'), (157, 170, 'TIME')],
#   [(43, 49, 'CITY'),
#    (52, 58, 'STATE_OR_PROVINCE'),
#    (77, 79, 'NUMBER'),
#    (89, 104, 'NUMBER'),
#    (59, 66, 'ORGANIZATION'),
#    (67, 87, 'EVENT'),
#    (16, 22, 'EVENT')],
#   [(44, 49, 'PRODUCT'),
#    (36, 41, 'PRODUCT'),
#    (44, 49, 'PRODUCT'),
#    (47, 49, 'NUMBER'),
#    (47, 49, 'NUMBER'),
#    (39, 41, 'NUMBER')],
#   [(2, 8, 'COUNTRY'), (15, 30, 'PROFESSION')],
#   [(35, 41, 'COUNTRY'),
#    (19, 34, 'PROFESSION'),
#    (6, 16, 'PERSON'),
#    (19, 34, 'PROFESSION'),
#    (19, 41, 'PROFESSION'),
#    (35, 41, 'COUNTRY')],
#   [(58, 64, 'COUNTRY'),
#    (40, 55, 'PROFESSION'),
#    (12, 22, 'PERSON'),
#    (40, 55, 'PROFESSION'),
#    (0, 11, 'DATE'),
#    (40, 57, 'PROFESSION'),
#    (12, 22, 'PERSON'),
#    (109, 128, 'PERSON'),
#    (40, 64, 'PROFESSION'),
#    (12, 22, 'PERSON'),
#    (27, 33, 'EVENT'),
#    (58, 64, 'COUNTRY'),
#    (58, 64, 'COUNTRY')],
#   [(54, 60, 'COUNTRY'),
#    (0, 15, 'PROFESSION'),
#    (0, 15, 'PROFESSION'),
#    (0, 15, 'PROFESSION'),
#    (64, 88, 'ORGANIZATION'),
#    (92, 95, 'PERSON'),
#    (110, 113, 'NUMBER'),
#    (117, 120, 'NUMBER'),
#    (151, 154, 'NUMBER'),
#    (158, 161, 'NUMBER'),
#    (163, 182, 'DATE'),
#    (225, 265, 'ORGANIZATION'),
#    (202, 265, 'PROFESSION'),
#    (20, 26, 'EVENT'),
#    (20, 26, 'EVENT'),
#    (29, 34, 'NUMBER'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (43, 60, 'ORGANIZATION'),
#    (43, 53, 'ORGANIZATION'),
#    (43, 53, 'ORGANIZATION'),
#    (35, 60, 'ORGANIZATION'),
#    (35, 53, 'ORGANIZATION'),
#    (134, 148, 'ORGANIZATION'),
#    (121, 130, 'PROFESSION'),
#    (92, 95, 'PERSON'),
#    (20, 26, 'EVENT'),
#    (225, 258, 'ORGANIZATION'),
#    (54, 60, 'COUNTRY'),
#    (225, 251, 'IDEOLOGY'),
#    (96, 109, 'EVENT')],
#   [(16, 19, 'PERSON'),
#    (16, 19, 'PERSON'),
#    (58, 66, 'PERSON'),
#    (16, 19, 'PERSON'),
#    (190, 204, 'COUNTRY'),
#    (229, 235, 'COUNTRY'),
#    (16, 19, 'PERSON')],
#   [(0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (50, 58, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (50, 58, 'PERSON'),
#    (35, 44, 'PROFESSION'),
#    (0, 3, 'PERSON'),
#    (20, 34, 'IDEOLOGY')],
#   [],
#   [(54, 60, 'COUNTRY'),
#    (38, 53, 'PROFESSION'),
#    (38, 53, 'PROFESSION'),
#    (152, 169, 'PROFESSION'),
#    (38, 53, 'PROFESSION'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (31, 37, 'ORDINAL'),
#    (84, 104, 'EVENT'),
#    (117, 125, 'AGE'),
#    (0, 3, 'PERSON'),
#    (38, 60, 'PROFESSION'),
#    (152, 176, 'PROFESSION'),
#    (38, 53, 'PROFESSION'),
#    (38, 60, 'PROFESSION'),
#    (152, 176, 'PROFESSION'),
#    (152, 169, 'PROFESSION'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (0, 3, 'PERSON'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (12, 23, 'DATE')],
#   [(51, 66, 'PROFESSION'),
#    (120, 130, 'PERSON'),
#    (51, 66, 'PROFESSION'),
#    (51, 68, 'PROFESSION'),
#    (120, 130, 'PERSON'),
#    (51, 66, 'PROFESSION'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (51, 68, 'PROFESSION'),
#    (81, 106, 'PROFESSION'),
#    (51, 66, 'PROFESSION'),
#    (51, 68, 'PROFESSION'),
#    (24, 33, 'PROFESSION'),
#    (59, 68, 'PROFESSION'),
#    (120, 130, 'PERSON'),
#    (0, 3, 'PERSON'),
#    (120, 130, 'PERSON'),
#    (108, 119, 'DATE')],
#   [(191, 197, 'COUNTRY'),
#    (12, 15, 'PERSON'),
#    (157, 197, 'ORGANIZATION'),
#    (12, 15, 'PERSON'),
#    (97, 105, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (97, 105, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (12, 15, 'PERSON'),
#    (0, 11, 'DATE'),
#    (18, 25, 'PROFESSION'),
#    (48, 59, 'DATE'),
#    (97, 105, 'PERSON'),
#    (134, 156, 'PROFESSION'),
#    (18, 46, 'PROFESSION'),
#    (134, 197, 'PROFESSION'),
#    (191, 197, 'COUNTRY'),
#    (191, 197, 'COUNTRY'),
#    (191, 197, 'COUNTRY'),
#    (36, 46, 'ORGANIZATION'),
#    (36, 46, 'ORGANIZATION'),
#    (12, 15, 'PERSON'),
#    (157, 190, 'ORGANIZATION'),
#    (191, 197, 'COUNTRY'),
#    (157, 183, 'IDEOLOGY'),
#    (191, 197, 'COUNTRY'),
#    (191, 197, 'COUNTRY'),
#    (12, 15, 'PERSON'),
#    (26, 46, 'ORGANIZATION'),
#    (36, 46, 'ORGANIZATION'),
#    (26, 35, 'COUNTRY'),
#    (12, 15, 'PERSON'),
#    (90, 94, 'PERSON'),
#    (157, 197, 'ORGANIZATION'),
#    (191, 197, 'COUNTRY'),
#    (157, 183, 'IDEOLOGY'),
#    (157, 190, 'ORGANIZATION'),
#    (75, 94, 'ORGANIZATION')],
#   [(0, 8, 'PROFESSION'), (38, 50, 'CITY'), (19, 37, 'ORGANIZATION')],
#   [(17, 21, 'ORGANIZATION')],
#   [(124, 128, 'ORGANIZATION'),
#    (0, 28, 'TIME'),
#    (20, 28, 'DATE'),
#    (31, 43, 'CITY'),
#    (93, 122, 'ORGANIZATION'),
#    (124, 128, 'ORGANIZATION'),
#    (161, 170, 'AGE'),
#    (171, 185, 'PERSON'),
#    (187, 201, 'PERSON'),
#    (206, 214, 'PROFESSION'),
#    (340, 343, 'NUMBER'),
#    (347, 350, 'NUMBER'),
#    (162, 163, 'NUMBER'),
#    (342, 343, 'NUMBER'),
#    (433, 437, 'NUMBER'),
#    (490, 514, 'ORGANIZATION'),
#    (31, 43, 'CITY'),
#    (533, 547, 'DATE'),
#    (55, 61, 'EVENT'),
#    (93, 115, 'IDEOLOGY'),
#    (497, 514, 'IDEOLOGY'),
#    (69, 122, 'PROFESSION')],
#   [(20, 29, 'DATE'),
#    (20, 35, 'TIME'),
#    (58, 75, 'EVENT'),
#    (142, 153, 'DATE'),
#    (177, 189, 'CITY'),
#    (213, 221, 'COUNTRY'),
#    (230, 244, 'PERSON'),
#    (248, 263, 'PROFESSION'),
#    (281, 336, 'PROFESSION'),
#    (385, 391, 'ORDINAL'),
#    (236, 244, 'PERSON'),
#    (177, 189, 'CITY'),
#    (222, 229, 'PROFESSION'),
#    (253, 263, 'ORGANIZATION'),
#    (296, 336, 'ORGANIZATION'),
#    (318, 326, 'COUNTRY'),
#    (327, 336, 'RELIGION'),
#    (69, 75, 'EVENT')],
#   [(207, 211, 'ORGANIZATION'),
#    (207, 211, 'ORGANIZATION'),
#    (99, 111, 'CITY'),
#    (114, 122, 'COUNTRY'),
#    (447, 461, 'PERSON'),
#    (46, 54, 'PERSON'),
#    (46, 54, 'PERSON'),
#    (99, 111, 'CITY'),
#    (114, 122, 'COUNTRY'),
#    (125, 137, 'PERSON'),
#    (146, 153, 'PROFESSION'),
#    (164, 184, 'PROFESSION'),
#    (207, 211, 'ORGANIZATION'),
#    (224, 242, 'DATE'),
#    (243, 254, 'PROFESSION'),
#    (99, 110, 'CITY'),
#    (321, 360, 'ORGANIZATION'),
#    (369, 394, 'STATE_OR_PROVINCE'),
#    (447, 461, 'PERSON'),
#    (99, 110, 'CITY'),
#    (514, 521, 'CITY'),
#    (545, 556, 'EVENT'),
#    (675, 686, 'PROFESSION'),
#    (687, 703, 'PERSON'),
#    (99, 111, 'CITY'),
#    (343, 360, 'IDEOLOGY'),
#    (557, 565, 'COUNTRY'),
#    (566, 575, 'RELIGION'),
#    (185, 199, 'CITY'),
#    (185, 211, 'ORGANIZATION'),
#    (361, 394, 'CITY'),
#    (545, 575, 'EVENT'),
#    (468, 477, 'EVENT'),
#    (256, 267, 'PROFESSION')],
#   [(153, 154, 'NUMBER'),
#    (143, 152, 'DATE'),
#    (406, 420, 'PERSON'),
#    (412, 420, 'PERSON'),
#    (412, 420, 'PERSON'),
#    (43, 55, 'PERSON'),
#    (406, 420, 'PERSON'),
#    (173, 189, 'PERSON'),
#    (43, 55, 'PERSON'),
#    (112, 119, 'PERSON'),
#    (143, 161, 'DATE'),
#    (173, 189, 'PERSON'),
#    (239, 281, 'PROFESSION'),
#    (406, 420, 'PERSON'),
#    (252, 281, 'ORGANIZATION'),
#    (25, 34, 'EVENT'),
#    (25, 34, 'EVENT')],
#   [(236, 240, 'ORGANIZATION'),
#    (236, 240, 'ORGANIZATION'),
#    (236, 240, 'ORGANIZATION'),
#    (57, 64, 'PERSON'),
#    (211, 214, 'ORGANIZATION'),
#    (236, 240, 'ORGANIZATION'),
#    (30, 47, 'IDEOLOGY'),
#    (158, 165, 'PROFESSION'),
#    (30, 47, 'ORGANIZATION'),
#    (186, 198, 'RELIGION'),
#    (186, 209, 'IDEOLOGY')],
#   [(0, 6, 'PERSON'),
#    (19, 30, 'PROFESSION'),
#    (42, 50, 'PERSON'),
#    (19, 39, 'PROFESSION'),
#    (31, 39, 'COUNTRY'),
#    (7, 16, 'EVENT')],
#   [(5, 11, 'PERSON'),
#    (1, 11, 'PERSON'),
#    (43, 57, 'PERSON'),
#    (58, 72, 'PERSON'),
#    (24, 42, 'PROFESSION'),
#    (24, 38, 'PROFESSION'),
#    (39, 42, 'COUNTRY')],
#   [(23, 29, 'PERSON'),
#    (44, 55, 'PROFESSION'),
#    (19, 29, 'PERSON'),
#    (0, 14, 'PROFESSION'),
#    (19, 29, 'PERSON'),
#    (44, 55, 'PROFESSION'),
#    (65, 80, 'PERSON'),
#    (91, 107, 'PERSON'),
#    (44, 64, 'PROFESSION'),
#    (56, 64, 'COUNTRY'),
#    (15, 18, 'COUNTRY'),
#    (0, 18, 'PROFESSION'),
#    (15, 18, 'COUNTRY'),
#    (44, 64, 'PROFESSION'),
#    (56, 64, 'COUNTRY'),
#    (32, 41, 'EVENT'),
#    (30, 41, 'EVENT')],
#   [(0, 6, 'PERSON'), (0, 6, 'PERSON'), (23, 31, 'PERSON'), (23, 30, 'PERSON')],
#   [(34, 41, 'PERSON'),
#    (0, 6, 'PERSON'),
#    (34, 42, 'PERSON'),
#    (55, 65, 'COUNTRY')],
#   [(14, 20, 'PERSON'),
#    (14, 20, 'PERSON'),
#    (37, 43, 'PERSON'),
#    (14, 22, 'PERSON'),
#    (37, 43, 'PERSON'),
#    (79, 89, 'NATIONALITY'),
#    (53, 66, 'DATE'),
#    (2, 11, 'EVENT')],
#   [(35, 42, 'DATE'), (15, 21, 'EVENT')],
#   [(40, 48, 'PERSON'),
#    (40, 47, 'PERSON'),
#    (0, 9, 'ORGANIZATION'),
#    (40, 48, 'PERSON'),
#    (28, 37, 'EVENT')],
#   [(82, 90, 'PERSON'),
#    (82, 89, 'PERSON'),
#    (7, 15, 'COUNTRY'),
#    (82, 90, 'PERSON'),
#    (7, 15, 'COUNTRY'),
#    (7, 15, 'COUNTRY'),
#    (0, 15, 'ORGANIZATION')],
#   [(20, 34, 'PERSON'),
#    (27, 34, 'PERSON'),
#    (252, 260, 'COUNTRY'),
#    (20, 34, 'PERSON'),
#    (73, 85, 'COUNTRY'),
#    (162, 173, 'CITY'),
#    (184, 195, 'FACILITY'),
#    (217, 225, 'STATE_OR_PROVINCE'),
#    (252, 260, 'COUNTRY'),
#    (267, 271, 'COUNTRY'),
#    (252, 260, 'COUNTRY'),
#    (252, 260, 'COUNTRY'),
#    (109, 120, 'CRIME')],
#   [(62, 69, 'PERSON'),
#    (62, 70, 'PERSON'),
#    (4, 16, 'COUNTRY'),
#    (40, 43, 'COUNTRY'),
#    (62, 70, 'PERSON'),
#    (40, 43, 'COUNTRY'),
#    (40, 43, 'COUNTRY'),
#    (17, 37, 'EVENT')],
#   [(103, 111, 'COUNTRY'),
#    (103, 111, 'COUNTRY'),
#    (6, 13, 'COUNTRY'),
#    (55, 71, 'PERSON'),
#    (92, 111, 'ORGANIZATION'),
#    (114, 121, 'CITY'),
#    (103, 111, 'COUNTRY'),
#    (103, 111, 'COUNTRY'),
#    (45, 54, 'ORGANIZATION'),
#    (103, 111, 'COUNTRY'),
#    (14, 33, 'EVENT')],
#   [(51, 58, 'PERSON'),
#    (10, 16, 'PERSON'),
#    (51, 59, 'PERSON'),
#    (10, 16, 'PERSON'),
#    (30, 33, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (0, 9, 'PROFESSION'),
#    (30, 33, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (181, 192, 'NATIONALITY'),
#    (30, 33, 'COUNTRY'),
#    (30, 33, 'COUNTRY'),
#    (10, 16, 'PERSON')],
#   [(51, 58, 'PERSON'),
#    (51, 59, 'PERSON'),
#    (72, 82, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (22, 29, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (12, 21, 'PROFESSION'),
#    (51, 59, 'PERSON'),
#    (72, 82, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (12, 30, 'PROFESSION'),
#    (22, 30, 'COUNTRY')],
#   [(108, 115, 'PERSON'),
#    (128, 135, 'COUNTRY'),
#    (13, 25, 'COUNTRY'),
#    (108, 117, 'PERSON'),
#    (128, 136, 'COUNTRY')],
#   [(129, 136, 'PERSON'),
#    (129, 137, 'PERSON'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (58, 65, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (129, 137, 'PERSON'),
#    (33, 49, 'ORGANIZATION'),
#    (58, 66, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (138, 150, 'COUNTRY'),
#    (138, 164, 'ORGANIZATION')],
#   [(25, 40, 'PERSON')],
#   [(60, 76, 'DATE'), (118, 128, 'AGE'), (129, 135, 'PROFESSION')],
#   [(100, 108, 'NUMBER'), (178, 187, 'ORDINAL'), (50, 56, 'PROFESSION')],
#   [(1, 5, 'PRODUCT'),
#    (31, 34, 'FACILITY'),
#    (35, 45, 'TIME'),
#    (15, 28, 'EVENT')],
#   [(52, 56, 'PRODUCT'),
#    (135, 138, 'FACILITY'),
#    (0, 18, 'DATE'),
#    (0, 29, 'TIME'),
#    (52, 64, 'PRODUCT'),
#    (89, 97, 'FACILITY'),
#    (100, 133, 'FACILITY'),
#    (135, 138, 'FACILITY'),
#    (164, 177, 'TIME'),
#    (239, 244, 'FACILITY'),
#    (246, 257, 'COUNTRY'),
#    (135, 138, 'FACILITY'),
#    (66, 75, 'EVENT'),
#    (178, 188, 'TIME'),
#    (164, 188, 'TIME'),
#    (189, 202, 'EVENT'),
#    (189, 202, 'EVENT')],
#   [(35, 39, 'NUMBER'),
#    (40, 47, 'NATIONALITY'),
#    (50, 66, 'PERSON'),
#    (69, 87, 'PERSON'),
#    (90, 94, 'NUMBER'),
#    (95, 105, 'NATIONALITY'),
#    (108, 125, 'PERSON'),
#    (171, 187, 'DATE'),
#    (50, 66, 'PERSON'),
#    (223, 238, 'DATE'),
#    (268, 276, 'AGE'),
#    (297, 303, 'ORDINAL'),
#    (189, 205, 'PROFESSION'),
#    (304, 321, 'EVENT')],
#   [(63, 67, 'PRODUCT'),
#    (9, 12, 'FACILITY'),
#    (9, 12, 'FACILITY'),
#    (122, 129, 'NATIONALITY'),
#    (150, 160, 'NATIONALITY'),
#    (63, 75, 'PRODUCT'),
#    (95, 102, 'NATIONALITY'),
#    (103, 120, 'PERSON'),
#    (122, 131, 'NATIONALITY'),
#    (132, 147, 'PERSON'),
#    (150, 160, 'NATIONALITY'),
#    (161, 175, 'PERSON'),
#    (9, 12, 'FACILITY'),
#    (9, 12, 'FACILITY'),
#    (23, 34, 'PROFESSION'),
#    (78, 94, 'PROFESSION'),
#    (51, 75, 'ORGANIZATION')],
#   [(39, 41, 'NUMBER'), (57, 59, 'NUMBER'), (107, 108, 'NUMBER')],
#   [(45, 48, 'FACILITY'),
#    (45, 48, 'FACILITY'),
#    (55, 61, 'ORDINAL'),
#    (116, 125, 'TIME'),
#    (177, 195, 'DATE'),
#    (45, 48, 'FACILITY'),
#    (45, 48, 'FACILITY'),
#    (45, 48, 'FACILITY')],
#   [(275, 279, 'PRODUCT'),
#    (275, 287, 'PRODUCT'),
#    (39, 51, 'TIME'),
#    (209, 234, 'TIME'),
#    (275, 287, 'PRODUCT'),
#    (289, 306, 'PERSON'),
#    (347, 356, 'DATE'),
#    (357, 366, 'ORGANIZATION'),
#    (256, 273, 'PROFESSION'),
#    (256, 287, 'PROFESSION')],
#   [],
#   [(1, 8, 'WORK_OF_ART'), (44, 67, 'EVENT')],
#   [(0, 13, 'PERSON')],
#   [(112, 119, 'WORK_OF_ART'),
#    (26, 49, 'EVENT'),
#    (26, 49, 'EVENT'),
#    (50, 54, 'DATE'),
#    (75, 84, 'NATIONALITY'),
#    (95, 110, 'PERSON'),
#    (112, 119, 'WORK_OF_ART')],
#   [(0, 13, 'PERSON')],
#   ...])

# %%
dataset = list(zip(X_data, y_data))

# %%
dataset
# Out:
# [('Марк Цукерберг стал Человеком года',
#   [(0, 14, 'PERSON', 'B'), (20, 34, 'AWARD', 'B')]),
#  ('Журнал Time назвал Марка Цукерберга, основателя социальной сети Facebook с более чем половиной миллиарда пользователей по всему миру, Человеком года. По мнению редакции Time, в течение 2010 года Цукерберг существенным образом изменил жизнь миллионов людей и оказал огромное влияние на события, происходящие в мире. «Это не просто новая технология. Это социальная инженерия. Это меняет то, каким образом мы общаемся друг с другом. Я действительно думаю, что это влияет на человеческую природу так, как ещё никогда до этого», — сказал в эфире телеканала NBC главный редактор Time Ричард Стенгел.',
#   [(7, 11, 'ORGANIZATION', 'B'),
#    (19, 35, 'PERSON', 'B'),
#    (64, 72, 'PRODUCT', 'B'),
#    (75, 104, 'NUMBER', 'B'),
#    (7, 11, 'ORGANIZATION'),
#    (175, 194, 'DATE'),
#    (552, 555, 'ORGANIZATION'),
#    (556, 572, 'PROFESSION'),
#    (578, 592, 'PERSON'),
#    (134, 148, 'AWARD'),
#    (134, 148, 'AWARD'),
#    (25, 34, 'PERSON'),
#    (240, 249, 'NUMBER'),
#    (7, 11, 'ORGANIZATION'),
#    (556, 577, 'PROFESSION')]),
#  ('26-летний Цукерберг стал самым молодым победителем в этой номинации в истории — с тех пор, как в 1927 году первым Человеком года был назван пилот Чарльз Линдберг, в одиночку перелетевший Атлантический океан.',
#   [(0, 9, 'AGE', 'B'),
#    (10, 19, 'PERSON', 'B'),
#    (95, 106, 'DATE', 'B'),
#    (140, 145, 'PROFESSION', 'B'),
#    (146, 161, 'PERSON', 'B'),
#    (187, 206, 'LOCATION', 'B'),
#    (114, 128, 'AWARD'),
#    (114, 128, 'AWARD'),
#    (10, 19, 'PERSON'),
#    (114, 128, 'AWARD')]),
#  ('Впрочем, решение относительно Цукерберга далось Time с большим трудом: победителем читательского голосования на сайте журнала стал основатель WikiLeaks Джулиан Ассанж, однако итоговое решение редакции оказалось не в его пользу. Надо думать, по политическим соображениям.',
#   [(48, 52, 'ORGANIZATION', 'B'),
#    (48, 52, 'ORGANIZATION'),
#    (30, 39, 'PERSON'),
#    (30, 40, 'PERSON'),
#    (48, 52, 'ORGANIZATION'),
#    (152, 166, 'PERSON'),
#    (30, 39, 'PERSON'),
#    (48, 52, 'ORGANIZATION'),
#    (142, 151, 'ORGANIZATION')]),
#  ('Серена Уильямс родила дочь',
#   [(0, 14, 'PERSON', 'B'), (15, 26, 'EVENT', 'B')]),
#  ('Серена Уильямс на корте', [(0, 14, 'PERSON', 'B'), (0, 14, 'PERSON', 'B')]),
#  ('Алексис Оганян (Alexis Ohanian) протестует против SOPA и PIPA в Нью-Йорке в 2012 году',
#   [(0, 14, 'PERSON', 'B'),
#    (16, 30, 'PERSON', 'B'),
#    (50, 54, 'ORGANIZATION', 'B'),
#    (57, 61, 'ORGANIZATION', 'B'),
#    (64, 73, 'CITY', 'B'),
#    (74, 85, 'DATE', 'B')]),
#  ('35-летняя американская теннисистка Серена Уильямс родила дочь, сообщают СМИ 1 сентября 2017 года.',
#   [(35, 49, 'PERSON', 'B'),
#    (35, 49, 'PERSON'),
#    (0, 2, 'AGE'),
#    (10, 22, 'NATIONALITY'),
#    (35, 49, 'PERSON'),
#    (76, 96, 'DATE'),
#    (50, 61, 'EVENT'),
#    (23, 34, 'PROFESSION'),
#    (50, 61, 'EVENT')]),
#  ('Роды прошли в клинике во Флориде.',
#   [(25, 32, 'STATE_OR_PROVINCE', 'B'), (0, 4, 'EVENT', 'B')]),
#  ('Вес новорождённой — 3090 граммов. Имя ребёнка не сообщается.',
#   [(20, 32, 'NUMBER', 'B')]),
#  ('Отец ребёнка — один из основателей Reddit американский интернет-предприниматель Алексис Оганян (Alexis Ohanian), с которым Серена помолвилась в 2016 году.',
#   [(80, 94, 'PERSON', 'B'),
#    (96, 110, 'PERSON', 'B'),
#    (35, 41, 'PRODUCT'),
#    (80, 94, 'PERSON'),
#    (96, 110, 'PERSON'),
#    (123, 129, 'PERSON'),
#    (142, 153, 'DATE'),
#    (42, 54, 'NATIONALITY'),
#    (55, 79, 'PROFESSION'),
#    (130, 141, 'EVENT')]),
#  ('Теннисистку уже поздравили её сестра Винус Уильямс и тренер Патрик Муратоглу. Он также пожелал ей как можно скорее набрать форму, добавив, что «впереди много работы».',
#   [(37, 50, 'PERSON', 'B'),
#    (53, 59, 'PROFESSION', 'B'),
#    (60, 76, 'PERSON', 'B'),
#    (0, 11, 'PROFESSION', 'B')]),
#  ('О своей беременности Уильямс-младшая объявила 19 апреля 2017 года, сообщив, что ожидает ребёнка к осени.',
#   [(21, 36, 'PERSON', 'B'), (46, 65, 'DATE', 'B'), (96, 103, 'DATE', 'B')]),
#  ('Несмотря на беременность, Уильямс выиграла в Австралии свой 23-й по счёту турнир серии Большого шлема в одиночном разряде.',
#   [(26, 33, 'PERSON', 'B'),
#    (45, 54, 'COUNTRY', 'B'),
#    (60, 62, 'ORDINAL', 'B'),
#    (87, 101, 'EVENT', 'B'),
#    (74, 101, 'EVENT')]),
#  ('Ранее Серена Уильямс заявляла, что не намерена надолго прерывать спортивную карьеру и планирует вернуться на корт уже в январе 2018 года.',
#   [(6, 20, 'PERSON', 'B'),
#    (6, 20, 'PERSON'),
#    (6, 20, 'PERSON'),
#    (6, 12, 'PERSON'),
#    (13, 20, 'PERSON'),
#    (6, 20, 'PERSON'),
#    (118, 136, 'DATE')]),
#  ('В планах Серены выиграть ещё один турнир Большого шлема, чтобы повторить рекорд, принадлежащий австралийской теннисистке Маргарет Корт, которая в 1960—1975 годах одержала 24 победы в турнирах «Большого шлема» в одиночном разряде.',
#   [(9, 15, 'PERSON', 'B'),
#    (95, 108, 'NATIONALITY', 'B'),
#    (121, 134, 'PERSON', 'B'),
#    (144, 161, 'DATE', 'B'),
#    (171, 173, 'NUMBER', 'B'),
#    (41, 55, 'EVENT'),
#    (41, 55, 'EVENT'),
#    (109, 120, 'PROFESSION'),
#    (41, 55, 'EVENT')]),
#  ('Предки Алексиса Оганяна приехали в США около 100 лет назад из Турции, спасаясь от Геноцида армян. Алексис вырос в Бруклине, в 22 года вместе со своим другом Стивом Хаффманом запустил стартап Reddit. Уже через год они продали сайт издательскому дому Conde Nast за восьмизначную сумму. Поработав в совете директоров, Оганян покинул компанию в 2010 году. Позже он занимался созданием венчурных компаний, благотворительных\u2002фондов и гражданским активизмом. Также Алексис пишет статьи для New York Times, Washington Post, Forbes и Economist и считается экспертом в области цифровой экономики. Об их романе с Уильямс впервые заговорили в 2015 году, когда на странице Алексиса в Instagram стали появляться фото с теннисных матчей.',
#   [(191, 197, 'PRODUCT', 'B'),
#    (602, 609, 'PERSON', 'B'),
#    (7, 23, 'PERSON'),
#    (35, 38, 'COUNTRY'),
#    (62, 68, 'COUNTRY'),
#    (82, 96, 'EVENT'),
#    (7, 14, 'PERSON'),
#    (114, 122, 'DISTRICT'),
#    (126, 133, 'AGE'),
#    (157, 173, 'PERSON'),
#    (191, 197, 'ORGANIZATION'),
#    (203, 212, 'DATE'),
#    (249, 259, 'ORGANIZATION'),
#    (263, 276, 'NUMBER'),
#    (16, 22, 'PERSON'),
#    (339, 350, 'DATE'),
#    (7, 14, 'PERSON'),
#    (483, 497, 'ORGANIZATION'),
#    (499, 514, 'ORGANIZATION'),
#    (516, 522, 'ORGANIZATION'),
#    (525, 534, 'ORGANIZATION'),
#    (602, 609, 'PERSON'),
#    (629, 640, 'DATE'),
#    (7, 15, 'PERSON'),
#    (39, 58, 'DATE'),
#    (91, 96, 'NATIONALITY'),
#    (671, 680, 'PRODUCT'),
#    (263, 282, 'MONEY'),
#    (483, 491, 'CITY'),
#    (499, 509, 'CITY')]),
#  ('В парламентских выборах Индонезии участвует Михаил Горбачёв',
#   [(24, 33, 'COUNTRY', 'B'),
#    (44, 59, 'PERSON', 'B'),
#    (16, 23, 'EVENT'),
#    (2, 23, 'EVENT')]),
#  ('Народный консультативный конгресс Индонезии',
#   [(34, 43, 'COUNTRY', 'B'),
#    (0, 43, 'ORGANIZATION', 'B'),
#    (0, 33, 'ORGANIZATION', 'B'),
#    (34, 43, 'COUNTRY')]),
#  ('На парламентских выборах в Индонезии свою кандидатуру выдвинул Михаил Горбачёв — местный житель, названный в честь бывшего президента СССР.',
#   [(27, 36, 'COUNTRY', 'B'),
#    (63, 78, 'PERSON', 'B'),
#    (27, 36, 'COUNTRY'),
#    (63, 78, 'PERSON'),
#    (17, 24, 'EVENT'),
#    (3, 24, 'EVENT'),
#    (3, 24, 'EVENT'),
#    (17, 24, 'EVENT'),
#    (27, 36, 'COUNTRY'),
#    (134, 138, 'COUNTRY'),
#    (123, 138, 'PROFESSION'),
#    (123, 133, 'PROFESSION')]),
#  ('Полное имя 32-летнего мужчины — Михаил Горбачёв Дом. Индонезиец рассказал, что назвали его так практически случайно: «Мои родители были уверены, что у них будет девочка. Когда я родился, они запаниковали, потому что они не подобрали имя для мальчика».',
#   [(32, 47, 'PERSON', 'B'),
#    (32, 47, 'PERSON'),
#    (11, 21, 'AGE'),
#    (32, 51, 'PERSON'),
#    (53, 63, 'NATIONALITY')]),
#  ('По его словам, примерно неделю после рождения у него вообще не было имени, а затем родители заметили в газете статью о Михаиле Горбачёве. Его отцу очень понравилось имя влиятельного человека и лидера страны, и в итоге сына решили назвать именно так.',
#   [(15, 30, 'DATE', 'B'),
#    (119, 136, 'PERSON', 'B'),
#    (193, 206, 'PROFESSION', 'B')]),
#  ('Дом отметил, что в юношестве ему было трудно и он до сих пор предпочитает, когда его называют Горба. В то же время имя «работает на пользу» его политической карьере. В политику он решил пойти после нескольких лет неэффективной природоохранной деятельности. Дом считает, что другим способом добиться изменений в сфере охраны окружающей среды просто не получится.',
#   [(94, 99, 'PERSON', 'B'),
#    (198, 212, 'DATE', 'B'),
#    (0, 3, 'PERSON', 'B'),
#    (0, 3, 'PERSON', 'B')]),
#  ('Горбачёв стал одним из 245 тысяч кандидатов на всеобщих выборах, которые пройдут в Индонезии 17 апреля. Это будет первое в истории страны голосование, в ходе которого одновременно будут выбирать президента, вице-президента, депутатов национального парламента и местных законодателей.',
#   [(83, 92, 'COUNTRY', 'B'),
#    (83, 92, 'COUNTRY'),
#    (0, 5, 'PERSON'),
#    (0, 8, 'PERSON'),
#    (23, 32, 'NUMBER'),
#    (47, 63, 'EVENT'),
#    (83, 92, 'COUNTRY'),
#    (114, 120, 'ORDINAL'),
#    (195, 205, 'PROFESSION'),
#    (207, 222, 'PROFESSION'),
#    (56, 63, 'EVENT'),
#    (56, 63, 'EVENT'),
#    (83, 92, 'COUNTRY'),
#    (195, 205, 'PROFESSION'),
#    (56, 63, 'EVENT'),
#    (93, 102, 'DATE'),
#    (224, 258, 'PROFESSION'),
#    (224, 233, 'PROFESSION'),
#    (261, 282, 'PROFESSION'),
#    (269, 282, 'PROFESSION'),
#    (234, 258, 'ORGANIZATION'),
#    (248, 258, 'ORGANIZATION')]),
#  ('Страна.ua: У Януковича в России родился третий сын',
#   [(0, 9, 'ORGANIZATION', 'B'),
#    (13, 22, 'PERSON', 'B'),
#    (25, 31, 'COUNTRY', 'B'),
#    (40, 46, 'ORDINAL', 'B'),
#    (32, 50, 'EVENT')]),
#  ('Виктор Янукович', [(0, 15, 'PERSON', 'B')]),
#  ('У бывшего президента Украины Виктора Януковича на территории России якобы родился сын, сообщает Страна.ua.',
#   [(96, 105, 'ORGANIZATION', 'B'),
#    (37, 46, 'PERSON'),
#    (61, 67, 'COUNTRY'),
#    (10, 28, 'PROFESSION'),
#    (29, 46, 'PERSON'),
#    (61, 67, 'COUNTRY'),
#    (96, 105, 'ORGANIZATION'),
#    (21, 28, 'COUNTRY'),
#    (74, 85, 'EVENT'),
#    (10, 20, 'PROFESSION')]),
#  ('Ребёнок появился на свет около трёх назад, после того, как Янукович бежал из Украины в Россию в 2014 году.',
#   [(25, 41, 'DATE', 'B'),
#    (59, 67, 'PERSON', 'B'),
#    (77, 84, 'COUNTRY', 'B'),
#    (87, 93, 'COUNTRY', 'B'),
#    (77, 84, 'COUNTRY'),
#    (94, 105, 'DATE'),
#    (68, 73, 'EVENT'),
#    (0, 24, 'EVENT')]),
#  ('По данным Страна.ua, матерью ребёнка является гражданская супруга политика сестрой его бывшей кухарки Любовь Полежай.',
#   [(10, 19, 'ORGANIZATION', 'B'),
#    (10, 19, 'ORGANIZATION'),
#    (10, 19, 'ORGANIZATION'),
#    (94, 101, 'PROFESSION'),
#    (102, 116, 'PERSON')]),
#  ('В феврале 2017 года Виктор Фёдорович дал интервью немецкой газете Der Spiegel, в котором рассказал, что расстался с женой Людмилой, после около 45 лет совместной жизни, и подтвердил, что живёт в неофициальном браке с Любовью Полежай.',
#   [(0, 19, 'DATE', 'B'),
#    (50, 58, 'COUNTRY', 'B'),
#    (66, 77, 'ORGANIZATION', 'B'),
#    (122, 130, 'PERSON', 'B'),
#    (138, 150, 'DATE', 'B'),
#    (217, 232, 'PERSON', 'B'),
#    (20, 36, 'PERSON'),
#    (104, 113, 'EVENT')]),
#  ('Однако позже пресс-служба Януковича опровергла эту информацию сообщив, что германские журналисты его не совсем правильно поняли.',
#   [(26, 35, 'PERSON', 'B'),
#    (26, 34, 'PERSON'),
#    (75, 85, 'NATIONALITY'),
#    (26, 35, 'PERSON'),
#    (86, 96, 'PROFESSION')]),
#  ('У Януковича от брака с первой женой Людмилой родились два сына: Александр и Виктор. Младший сын Виктор Янукович погиб в 2015 году во время ледовых автогонок на Байкале.',
#   [(2, 11, 'PERSON', 'B'),
#    (96, 111, 'PERSON', 'B'),
#    (2, 10, 'PERSON'),
#    (36, 44, 'PERSON'),
#    (2, 11, 'PERSON'),
#    (36, 44, 'PERSON'),
#    (54, 57, 'NUMBER'),
#    (64, 73, 'PERSON'),
#    (76, 82, 'PERSON'),
#    (96, 111, 'PERSON'),
#    (118, 129, 'DATE'),
#    (160, 167, 'STATE_OR_PROVINCE'),
#    (2, 11, 'PERSON'),
#    (112, 117, 'EVENT'),
#    (139, 156, 'EVENT'),
#    (147, 156, 'EVENT')]),
#  ('Бывшая супруга Януковича Людмила на данный момент проживает в Крыму.',
#   [(15, 24, 'PERSON', 'B'),
#    (15, 23, 'PERSON'),
#    (15, 24, 'PERSON'),
#    (62, 67, 'STATE_OR_PROVINCE'),
#    (15, 24, 'PERSON'),
#    (15, 24, 'PERSON'),
#    (25, 32, 'PERSON')]),
#  ('По данным Страна.ua, у 42-летней Полежай (в девичестве Садыкова) - есть 15-летняя дочь Мария от первого брака.',
#   [(10, 19, 'ORGANIZATION', 'B'),
#    (10, 19, 'ORGANIZATION'),
#    (10, 19, 'ORGANIZATION'),
#    (10, 19, 'ORGANIZATION'),
#    (23, 32, 'AGE'),
#    (55, 63, 'PERSON'),
#    (72, 81, 'AGE'),
#    (87, 92, 'PERSON'),
#    (96, 103, 'ORDINAL'),
#    (33, 40, 'PERSON')]),
#  ('Девочка вместе с мамой жила в особняке Януковича под Киевом в Межигорье, а потом уехала в Ростов.',
#   [(39, 48, 'PERSON', 'B'),
#    (39, 47, 'PERSON'),
#    (39, 48, 'PERSON'),
#    (30, 48, 'FACILITY'),
#    (53, 59, 'CITY'),
#    (62, 71, 'CITY'),
#    (90, 96, 'CITY'),
#    (39, 48, 'PERSON'),
#    (39, 48, 'PERSON'),
#    (39, 48, 'PERSON')]),
#  ('Родилась Любовь Полежай в Енакиево (Донецкая область) на Донбассе — там же, где родился и Янукович.',
#   [(90, 98, 'PERSON', 'B'),
#    (9, 23, 'PERSON'),
#    (9, 23, 'PERSON'),
#    (26, 34, 'CITY'),
#    (36, 52, 'STATE_OR_PROVINCE'),
#    (57, 65, 'LOCATION'),
#    (90, 98, 'PERSON'),
#    (16, 23, 'PERSON')]),
#  ('До бегства с Украины Любовь владела салоном красоты \'\'Crystal Spa\'\' и руководила благотворительным фондом "Дорога будущего".',
#   [(13, 20, 'COUNTRY', 'B'),
#    (13, 20, 'COUNTRY'),
#    (54, 65, 'ORGANIZATION'),
#    (107, 122, 'ORGANIZATION'),
#    (13, 20, 'COUNTRY'),
#    (21, 27, 'PERSON'),
#    (3, 10, 'EVENT')]),
#  ('В КНР женщину убило током во время разговора по iPhone',
#   [(2, 5, 'COUNTRY', 'B'), (48, 54, 'PRODUCT', 'B'), (14, 25, 'EVENT')]),
#  ('23-летнюю жительницу Китая из Синьцзян-Уйгурского автономного района Ма Ай Лунь убило током. Китаянка погибла, когда пыталась ответить на звонок на своём iPhone, подключённом к зарядному устройству.',
#   [(154, 160, 'PRODUCT', 'B'),
#    (0, 9, 'AGE', 'B'),
#    (21, 26, 'COUNTRY'),
#    (30, 68, 'DISTRICT'),
#    (69, 79, 'PERSON'),
#    (93, 101, 'NATIONALITY'),
#    (154, 160, 'PRODUCT'),
#    (80, 91, 'EVENT'),
#    (80, 91, 'EVENT'),
#    (102, 109, 'EVENT')]),
#  ('Местная полиция подтвердила, что гибель молодой женщины действительно произошла в результате удара током. Однако правоохранительные органы не уточняют, что причиной гибели китаянки стал именно смартфон.',
#   [(172, 180, 'NATIONALITY', 'B'),
#    (8, 15, 'ORGANIZATION'),
#    (33, 39, 'EVENT'),
#    (113, 138, 'ORGANIZATION'),
#    (165, 171, 'EVENT')]),
#  ('Узнав о происшествии, компания Apple выразила соболезнования родственникам погибшей. В заявлении корпорации говорится, что она готова расследовать данный инцидент и сотрудничать со следствием.',
#   [(31, 36, 'ORGANIZATION', 'B')]),
#  ('Одолев в четвертьфинале канадцев, сборная Россия была разгромлена финнами',
#   [(42, 48, 'COUNTRY', 'B'),
#    (66, 73, 'NATIONALITY', 'B'),
#    (24, 32, 'NATIONALITY'),
#    (34, 48, 'ORGANIZATION'),
#    (9, 23, 'EVENT')]),
#  ('Сборная России по хоккею, одержав 12 мая победу со счетом 2:1 над командой Канады в четвертьфинале чемпионата мира в Словакии, уже на следующий день потерпела в полуфинале сокрушительное поражение со счётом 0:3 от финнов.',
#   [(8, 14, 'COUNTRY', 'B'),
#    (34, 40, 'DATE', 'B'),
#    (35, 36, 'NUMBER'),
#    (75, 81, 'COUNTRY'),
#    (117, 125, 'COUNTRY'),
#    (131, 148, 'DATE'),
#    (207, 208, 'NUMBER'),
#    (214, 220, 'NATIONALITY'),
#    (84, 98, 'EVENT'),
#    (0, 24, 'ORGANIZATION'),
#    (84, 114, 'EVENT'),
#    (99, 114, 'EVENT'),
#    (66, 81, 'ORGANIZATION'),
#    (161, 171, 'EVENT'),
#    (0, 14, 'ORGANIZATION'),
#    (209, 210, 'NUMBER'),
#    (34, 35, 'NUMBER')]),
#  ('Первые два периода встречи с канадцами россияне проигрывали, затем в середине третьего периода сравнять счёт удалось Алексею Кайгородову. А на 53-й минуте Илья Ковальчук забросил решающую шайбу. Благодаря ему три года назад россияне уже одерживали победу над канадцами в Квебеке. Канада, не потерпевшая в Словакии до матча с россиянами ни одного поражения, завершила на этом своё выступление на мировом первенстве.',
#   [(305, 313, 'COUNTRY', 'B'),
#    (0, 6, 'ORDINAL', 'B'),
#    (29, 38, 'NATIONALITY'),
#    (117, 136, 'PERSON'),
#    (140, 154, 'TIME'),
#    (155, 169, 'PERSON'),
#    (209, 223, 'DATE'),
#    (29, 38, 'NATIONALITY'),
#    (271, 278, 'CITY'),
#    (280, 286, 'COUNTRY'),
#    (305, 313, 'COUNTRY'),
#    (325, 335, 'NATIONALITY'),
#    (39, 47, 'NATIONALITY'),
#    (39, 47, 'NATIONALITY'),
#    (7, 10, 'NUMBER'),
#    (78, 86, 'ORDINAL'),
#    (19, 26, 'EVENT'),
#    (144, 145, 'NUMBER')]),
#  ('В полуфинале, куда Россия вышла благодаря победе над Канадой, команда под руководством Вячеслава Быкова встретилась со сборной Финляндии. Российская команда, потерпевшая от финнов поражение по буллитам в игре в ходе отборочного раунда, и на этот раз не смогла взять верх. Первая шайба была заброшена в середине второго периода 19-летним финским дарованием Микаэлем Гранлундом потрясающим по красоте броском из-за ворот: подняв шайбу на крюке, он занёс её ворота над плечом голкипера россиян Константина Барулина. Россияне пытались отыграться, но безуспешно, а в третьем периоде сначала Яни Лаюнен, а затем Яркко Иммонен в большинстве довели счёт до разгромного.',
#   [(19, 25, 'COUNTRY', 'B'),
#    (173, 179, 'NATIONALITY', 'B'),
#    (19, 25, 'COUNTRY'),
#    (53, 60, 'COUNTRY'),
#    (87, 103, 'PERSON'),
#    (127, 136, 'COUNTRY'),
#    (138, 148, 'COUNTRY'),
#    (173, 179, 'NATIONALITY'),
#    (272, 278, 'ORDINAL'),
#    (327, 336, 'AGE'),
#    (356, 375, 'PERSON'),
#    (473, 482, 'PROFESSION'),
#    (483, 490, 'NATIONALITY'),
#    (491, 511, 'PERSON'),
#    (513, 521, 'NATIONALITY'),
#    (562, 569, 'ORDINAL'),
#    (586, 596, 'PERSON'),
#    (606, 619, 'PERSON'),
#    (2, 12, 'EVENT'),
#    (2, 12, 'EVENT'),
#    (119, 136, 'ORGANIZATION'),
#    (337, 344, 'NATIONALITY'),
#    (216, 234, 'EVENT'),
#    (311, 318, 'ORDINAL'),
#    (327, 328, 'NUMBER')]),
#  ('Теперь сборная России сразится за бронзовые награды с чехами, проигравшими во втором полуфинале соперникам из Швеции со счётом 2:5.',
#   [(15, 21, 'COUNTRY', 'B'),
#    (127, 128, 'NUMBER', 'B'),
#    (15, 21, 'COUNTRY'),
#    (54, 60, 'NATIONALITY'),
#    (78, 84, 'ORDINAL'),
#    (110, 116, 'COUNTRY'),
#    (127, 128, 'NUMBER'),
#    (85, 95, 'EVENT'),
#    (85, 95, 'EVENT'),
#    (7, 21, 'ORGANIZATION'),
#    (34, 51, 'AWARD'),
#    (78, 95, 'EVENT'),
#    (129, 130, 'NUMBER')]),
#  ('Рукопись Анны Франк ушла с молотка за 140 тысяч евро',
#   [(9, 19, 'PERSON', 'B'),
#    (38, 52, 'MONEY', 'B'),
#    (20, 34, 'EVENT'),
#    (0, 19, 'WORK_OF_ART')]),
#  ('Анна Франк', [(0, 10, 'PERSON', 'B')]),
#  ('На аукционе в Нидерландах рукопись стихотворения Анны Франк из восьми строчек продана за 140 тысяч евро.',
#   [(49, 59, 'PERSON', 'B'),
#    (89, 103, 'MONEY', 'B'),
#    (14, 25, 'COUNTRY'),
#    (49, 59, 'PERSON'),
#    (63, 69, 'NUMBER'),
#    (89, 103, 'MONEY'),
#    (78, 85, 'EVENT'),
#    (26, 59, 'WORK_OF_ART')]),
#  ('Стихотворение, датированное мартом 1942 года, было написано незадолго до того, как Анне и её семье пришлось укрыться от нацистов в секретной квартире в Амстердаме.',
#   [(28, 44, 'DATE', 'B'),
#    (83, 87, 'PERSON', 'B'),
#    (152, 162, 'CITY', 'B'),
#    (120, 128, 'IDEOLOGY')]),
#  ('К стихотворению приложено письмо о его подлинности авторства школьной подруги Анны, Жаклин ван Маарсен. Стихотворение посвящено сестре ван Маарсен, Кристиане.',
#   [(84, 102, 'PERSON', 'B'),
#    (148, 157, 'PERSON', 'B'),
#    (78, 82, 'PERSON'),
#    (91, 102, 'PERSON')]),
#  ('Стартовая цена лота составила 50 тысяч евро. Маатье Мостарт, представитель фонда Анны Франк, сказал, что подлинность рукописи не вызывает сомнений.',
#   [(81, 91, 'PERSON', 'B'),
#    (81, 91, 'PERSON'),
#    (30, 43, 'MONEY'),
#    (45, 59, 'PERSON'),
#    (61, 91, 'PROFESSION'),
#    (81, 85, 'PERSON'),
#    (81, 91, 'PERSON'),
#    (75, 91, 'ORGANIZATION')]),
#  ('История о трагической судьбе 15-летней еврейской девочки Анны Франк обошла весь мир. Анна погибла в нацистском концлагере незадолго до конца войны, но её отец Отто выжил и после освобождения из лагеря опубликовал её дневник.',
#   [(57, 67, 'PERSON', 'B'),
#    (57, 67, 'PERSON'),
#    (29, 38, 'AGE'),
#    (57, 67, 'PERSON'),
#    (85, 89, 'PERSON'),
#    (159, 163, 'PERSON'),
#    (57, 61, 'PERSON'),
#    (57, 67, 'PERSON'),
#    (39, 48, 'NATIONALITY'),
#    (100, 110, 'IDEOLOGY')]),
#  ('«Дневник Анны Франк» превратился в один из самых ярких символов Холокоста. В 2009 году «Дневник Анны Франк» был внесён в список Всемирного мемориального наследия ЮНЕСКО.',
#   [(9, 19, 'PERSON', 'B'),
#    (9, 19, 'PERSON'),
#    (9, 19, 'PERSON'),
#    (1, 19, 'WORK_OF_ART'),
#    (9, 19, 'PERSON'),
#    (75, 86, 'DATE'),
#    (1, 19, 'WORK_OF_ART'),
#    (9, 19, 'PERSON'),
#    (162, 168, 'ORGANIZATION'),
#    (9, 13, 'PERSON'),
#    (9, 19, 'PERSON'),
#    (64, 73, 'EVENT')]),
#  ('Сторонники экс-президента Йемена подтвердили сообщения о его гибели',
#   [(15, 32, 'PROFESSION', 'B'),
#    (26, 32, 'COUNTRY', 'B'),
#    (15, 25, 'PROFESSION'),
#    (61, 67, 'EVENT')]),
#  ('Али Абдалла Салех', [(0, 17, 'PERSON', 'B')]),
#  ('Бывший президент Йемена Али Абдалла Салех был убит, подтвердила в понедельник, 4 декабря 2017 года, его партия после появления в соцсетях видео с телом политика.',
#   [(24, 41, 'PERSON', 'B'),
#    (7, 23, 'PROFESSION'),
#    (24, 41, 'PERSON'),
#    (64, 98, 'DATE'),
#    (17, 23, 'COUNTRY'),
#    (17, 23, 'COUNTRY'),
#    (152, 160, 'PROFESSION'),
#    (46, 50, 'EVENT'),
#    (7, 16, 'PROFESSION')]),
#  ('«Он погиб мученической смертью, защищая республику», — заявил лидер Всеобщего народного конгресса Файка аль-Саид, обвинив в убийстве Салеха мятежников-хути (хуситами — шиитскими повстанцами).',
#   [(62, 97, 'PROFESSION', 'B'),
#    (98, 112, 'PERSON', 'B'),
#    (133, 139, 'PERSON', 'B'),
#    (68, 97, 'ORGANIZATION'),
#    (151, 155, 'IDEOLOGY'),
#    (157, 165, 'IDEOLOGY'),
#    (168, 177, 'RELIGION'),
#    (178, 189, 'IDEOLOGY'),
#    (124, 139, 'CRIME'),
#    (140, 150, 'IDEOLOGY'),
#    (124, 132, 'CRIME'),
#    (4, 9, 'EVENT')]),
#  ('75-летний Салех правил Йеменом более тридцати лет. В 2012 году он был отстранён от должности в результате общественных волнений и политического давления, однако продолжал закулисно участвовать в управлении страной, сформировав альянс с хути, которых поддерживает Иран.',
#   [(0, 9, 'AGE', 'B'),
#    (23, 30, 'COUNTRY', 'B'),
#    (31, 49, 'DATE', 'B'),
#    (51, 62, 'DATE', 'B'),
#    (263, 267, 'COUNTRY', 'B'),
#    (236, 240, 'IDEOLOGY'),
#    (10, 15, 'PERSON'),
#    (70, 92, 'EVENT'),
#    (236, 240, 'IDEOLOGY')]),
#  ('За два дня до смерти Салеха альянс, по-видимому, распался. В субботу, 2 декабря 2017 года, Салех выступил с критикой в адрес хути и предложил восстановить связи с Саудовской Аравией.',
#   [(21, 27, 'PERSON', 'B'),
#    (0, 10, 'DATE', 'B'),
#    (21, 27, 'PERSON'),
#    (59, 89, 'DATE'),
#    (21, 26, 'PERSON'),
#    (163, 181, 'COUNTRY'),
#    (125, 129, 'IDEOLOGY'),
#    (21, 26, 'PERSON'),
#    (125, 129, 'IDEOLOGY'),
#    (125, 129, 'IDEOLOGY'),
#    (14, 20, 'EVENT')]),
#  ('Мятежники, сообщившие о смерти политика ранее в понедельник, утверждают, что в момент убийства Салех направлялся в Саудовскую Аравию, и объясняют его гибель стремлением предотвратить попытку «переворота» против «альянса, в который он никогда не верил».',
#   [(95, 100, 'PERSON', 'B'),
#    (46, 59, 'DATE'),
#    (95, 100, 'PERSON'),
#    (115, 132, 'COUNTRY'),
#    (31, 39, 'PROFESSION'),
#    (95, 100, 'PERSON'),
#    (0, 9, 'IDEOLOGY'),
#    (86, 94, 'EVENT'),
#    (24, 30, 'EVENT'),
#    (150, 156, 'EVENT')]),
#  ('Стороны объединили силы три года назад и вынудили международно признанного президента страны Абду Рабу Мансура Хади бежать из страны и попросить о военном вмешательстве другие страны во главе с Саудовской Аравией.',
#   [(194, 212, 'COUNTRY', 'B'),
#    (24, 38, 'DATE'),
#    (75, 92, 'PROFESSION'),
#    (93, 115, 'PERSON'),
#    (194, 212, 'COUNTRY'),
#    (75, 84, 'PROFESSION'),
#    (116, 132, 'EVENT'),
#    (75, 85, 'PROFESSION')]),
#  ('В недавнем телеобращении Салех призвал прекратить осаду йеменских портов и предложил в обмен «начать с чистого листа» и «разобраться с ними в позитивном духе».',
#   [(25, 30, 'PERSON', 'B'),
#    (25, 30, 'PERSON'),
#    (25, 30, 'PERSON'),
#    (56, 65, 'COUNTRY'),
#    (25, 30, 'PERSON')]),
#  ('Столкновения между хути и силами Салеха начались на прошлой неделе, когда он обвинил мятежников в нападении на его гигантскую мечеть в Сане и на его племянника — влиятельного командира сил специального назначения Тарека Салеха.',
#   [(33, 39, 'PERSON', 'B'),
#    (33, 39, 'PERSON'),
#    (33, 38, 'PERSON'),
#    (33, 38, 'PERSON'),
#    (33, 38, 'PERSON'),
#    (33, 39, 'PERSON'),
#    (49, 66, 'DATE'),
#    (135, 139, 'CITY'),
#    (175, 212, 'PROFESSION'),
#    (213, 226, 'PERSON'),
#    (19, 23, 'IDEOLOGY'),
#    (85, 95, 'IDEOLOGY'),
#    (33, 38, 'PERSON'),
#    (19, 23, 'IDEOLOGY'),
#    (19, 23, 'IDEOLOGY'),
#    (19, 23, 'IDEOLOGY'),
#    (85, 95, 'IDEOLOGY')]),
#  ('Убит заместитель муфтия Северной Осетии',
#   [(0, 4, 'EVENT', 'B'),
#    (24, 39, 'STATE_OR_PROVINCE', 'B'),
#    (5, 39, 'PROFESSION'),
#    (5, 23, 'PROFESSION')]),
#  ('В ночь на четверг 27 декабря 2012 года в пригороде Владикавказа был застрелен заместитель муфтия Северной Осетии 38-летний Ибрагим Дударов. По данным СКР, автомобиль с телом Дударова был обнаружен на обочине дороги.',
#   [(0, 38, 'TIME', 'B'),
#    (7, 38, 'DATE', 'B'),
#    (51, 63, 'CITY', 'B'),
#    (113, 122, 'AGE', 'B'),
#    (123, 138, 'PERSON', 'B'),
#    (150, 153, 'ORGANIZATION', 'B'),
#    (174, 182, 'PERSON', 'B'),
#    (97, 112, 'STATE_OR_PROVINCE'),
#    (68, 77, 'EVENT'),
#    (78, 112, 'PROFESSION'),
#    (78, 112, 'PROFESSION'),
#    (97, 112, 'STATE_OR_PROVINCE'),
#    (78, 96, 'PROFESSION'),
#    (78, 96, 'PROFESSION')]),
#  ('При осмотре места преступления следователями изъяты гильзы калибра девять миллиметров.',
#   [(31, 44, 'PROFESSION', 'B'), (67, 85, 'NUMBER', 'B')]),
#  ('Следствие рассматривает несколько версий преступления. В том числе, не исключает, что мусульманский священнослужитель мог быть убит с целью обострения межконфессиональной ситуации в этой северокавказской республике, основную массу населения которой составляют христиане.',
#   [(100, 117, 'PROFESSION', 'B'),
#    (86, 99, 'RELIGION'),
#    (187, 203, 'LOCATION'),
#    (260, 269, 'RELIGION'),
#    (86, 117, 'PROFESSION'),
#    (127, 131, 'EVENT')]),
#  ('По данным российских СМИ, в Северной Осетии проживает четверть миллиона мусульман. В республике действует 25 мечетей, однако ранее здесь почти не отмечалось активности радикальных исламистов.',
#   [(10, 20, 'COUNTRY', 'B'),
#    (28, 43, 'STATE_OR_PROVINCE', 'B'),
#    (54, 71, 'NUMBER', 'B'),
#    (106, 108, 'NUMBER', 'B'),
#    (28, 43, 'STATE_OR_PROVINCE'),
#    (28, 43, 'STATE_OR_PROVINCE'),
#    (72, 81, 'RELIGION'),
#    (180, 190, 'IDEOLOGY'),
#    (168, 190, 'IDEOLOGY')]),
#  ('Напомним, что последнее нападение на мусульманских священнослужителей на Северном Кавказе произошло в феврале 2012 года. Тогда в Пятигорске был взорван автомобиль заместителя муфтия Ставропольского края Курмана Исмаилова. Сам Исмаилов погиб.',
#   [(73, 89, 'LOCATION', 'B'),
#    (100, 119, 'DATE', 'B'),
#    (129, 139, 'CITY', 'B'),
#    (203, 220, 'PERSON', 'B'),
#    (211, 219, 'PERSON', 'B'),
#    (51, 69, 'PROFESSION'),
#    (163, 202, 'PROFESSION'),
#    (37, 46, 'RELIGION'),
#    (37, 50, 'RELIGION'),
#    (182, 202, 'STATE_OR_PROVINCE'),
#    (235, 240, 'EVENT'),
#    (37, 69, 'PROFESSION'),
#    (24, 33, 'EVENT'),
#    (144, 162, 'EVENT'),
#    (163, 181, 'PROFESSION'),
#    (82, 89, 'LOCATION')]),
#  ('Махмуд Аббас объявил о заморозке контактов с Израилем на всех уровнях',
#   [(0, 12, 'PERSON', 'B'), (45, 53, 'COUNTRY', 'B')]),
#  ('Погибшие в результате теракта полицейские', []),
#  ('Палестинский лидер Махмуд Аббас объявил о заморозке контактов с Израилем на всех уровнях. Поводом стала установка металлоискателей на священной для мусульман Храмовой горе, которая привела к вспышке насилия.',
#   [(19, 31, 'PERSON', 'B'),
#    (64, 72, 'COUNTRY', 'B'),
#    (19, 31, 'PERSON'),
#    (64, 72, 'COUNTRY'),
#    (158, 171, 'FACILITY'),
#    (0, 12, 'COUNTRY'),
#    (13, 18, 'PROFESSION'),
#    (148, 157, 'RELIGION'),
#    (0, 18, 'PROFESSION'),
#    (104, 130, 'EVENT')]),
#  ('Аббас сказал, что официальные контакты с Израилем будут приостановлены до тех пор, пока не будут удалены рамки-металлоискатели рядом с входом в мечеть Эль-Акса на Храмовой горе в Старом городе Иерусалима. Он обвинил Израиль в попытке взять под контроль место, священное как для мусульман, так и для иудеев.',
#   [(41, 49, 'COUNTRY', 'B'),
#    (41, 49, 'COUNTRY'),
#    (163, 176, 'FACILITY'),
#    (0, 5, 'PERSON'),
#    (41, 49, 'COUNTRY'),
#    (151, 159, 'FACILITY'),
#    (163, 176, 'FACILITY'),
#    (179, 192, 'DISTRICT'),
#    (216, 223, 'COUNTRY'),
#    (278, 287, 'RELIGION'),
#    (193, 203, 'CITY'),
#    (278, 287, 'RELIGION'),
#    (299, 305, 'RELIGION')]),
#  ('Израиль объяснил установку рамок соображениями безопасности после того, как неделю назад возле Храмовой горы были убиты двое израильских полицейских.',
#   [(0, 7, 'COUNTRY', 'B'),
#    (0, 7, 'COUNTRY', 'B'),
#    (76, 88, 'DATE', 'B'),
#    (95, 108, 'FACILITY', 'B'),
#    (120, 124, 'NUMBER', 'B'),
#    (125, 136, 'COUNTRY', 'B'),
#    (137, 148, 'PROFESSION', 'B'),
#    (114, 119, 'EVENT'),
#    (17, 32, 'EVENT')]),
#  ('Кроме того, израильские власти запретили мужчинам в возрасте до 50 лет въезжать в Старый город Иерусалима.',
#   [(12, 23, 'COUNTRY', 'B'),
#    (61, 70, 'AGE', 'B'),
#    (82, 94, 'DISTRICT', 'B'),
#    (95, 105, 'CITY', 'B'),
#    (95, 105, 'CITY'),
#    (12, 30, 'ORGANIZATION')]),
#  ('В пятницу в Восточном Иерусалиме рядом с Храмовой горой были убиты трое палестинцев и трое израильтян. После нападения вход на Храмовую гору был закрыт, а все посетители — эвакуированы.',
#   [(0, 9, 'DATE', 'B'),
#    (12, 32, 'LOCATION', 'B'),
#    (41, 55, 'FACILITY', 'B'),
#    (67, 71, 'NUMBER', 'B'),
#    (67, 71, 'NUMBER'),
#    (91, 101, 'NATIONALITY'),
#    (127, 140, 'FACILITY'),
#    (72, 83, 'NATIONALITY'),
#    (22, 32, 'COUNTRY'),
#    (61, 66, 'EVENT'),
#    (61, 66, 'EVENT')]),
#  ('Следом в Восточном Иерусалиме и на Западном берегу произошли столкновения между палестинскими демонстрантами и израильскими силами безопасности. Три палестинца были убиты, сотни человек получили ранения в результате столкновений.',
#   [(9, 29, 'LOCATION', 'B'),
#    (9, 29, 'LOCATION', 'B'),
#    (19, 29, 'CITY', 'B'),
#    (32, 50, 'LOCATION', 'B'),
#    (111, 123, 'COUNTRY', 'B'),
#    (145, 148, 'NUMBER', 'B'),
#    (172, 177, 'NUMBER', 'B'),
#    (19, 29, 'COUNTRY'),
#    (80, 93, 'NATIONALITY'),
#    (149, 159, 'NATIONALITY'),
#    (124, 143, 'ORGANIZATION'),
#    (165, 170, 'EVENT'),
#    (165, 170, 'EVENT'),
#    (61, 73, 'EVENT'),
#    (111, 143, 'ORGANIZATION'),
#    (216, 228, 'EVENT')]),
#  ('Волна насилия охватила Иерусалим после пятничных молитв, которые во многих местах проводились за пределами мечетей. Тысячи верующих отказались подниматься на Храмовую гору через рамки металлоискателей, расстелили молельные коврики на улицах и стали молиться. В некоторых случаях молитвы переросли в столкновения с силами безопасности Израиля.',
#   [(158, 171, 'FACILITY', 'B'),
#    (23, 32, 'CITY'),
#    (158, 171, 'FACILITY'),
#    (334, 341, 'COUNTRY'),
#    (314, 341, 'ORGANIZATION'),
#    (314, 333, 'ORGANIZATION'),
#    (299, 311, 'EVENT')]),
#  ('Вечером в пятницу стало известно о нападении на еврейское поселение к северу от Рамаллы на Западном берегу реки Иордан, жертвами которого стали трое израильтян. Вооружённый ножом палестинец смертельно ранил двух мужчин и женщину, сообщают израильские СМИ. Ещё одна женщина была доставлена в больницу.',
#   [(239, 250, 'COUNTRY', 'B'),
#    (144, 148, 'NUMBER'),
#    (144, 148, 'NUMBER'),
#    (149, 159, 'NATIONALITY'),
#    (88, 106, 'LOCATION'),
#    (0, 17, 'TIME'),
#    (8, 17, 'DATE'),
#    (91, 106, 'LOCATION'),
#    (144, 148, 'NUMBER'),
#    (207, 211, 'NUMBER'),
#    (239, 250, 'COUNTRY'),
#    (48, 57, 'NATIONALITY'),
#    (80, 87, 'CITY'),
#    (68, 87, 'LOCATION'),
#    (112, 118, 'LOCATION'),
#    (149, 159, 'NATIONALITY'),
#    (179, 189, 'NATIONALITY'),
#    (35, 67, 'EVENT'),
#    (190, 206, 'EVENT')]),
#  ('С конца 2015 года в Израиле зафиксирован всплеск нападений на израильтян со стороны палестинцев и израильских арабов. Всего за два года в результате таких нападений погибли 42 израильтянина.',
#   [(62, 72, 'NATIONALITY', 'B'),
#    (0, 17, 'DATE', 'B'),
#    (20, 27, 'COUNTRY'),
#    (62, 72, 'NATIONALITY'),
#    (98, 109, 'COUNTRY'),
#    (124, 135, 'DATE'),
#    (173, 175, 'NUMBER'),
#    (98, 109, 'COUNTRY'),
#    (84, 95, 'NATIONALITY'),
#    (176, 189, 'NATIONALITY'),
#    (84, 95, 'NATIONALITY'),
#    (98, 116, 'NATIONALITY'),
#    (62, 72, 'NATIONALITY')]),
#  ('За то же время были убиты более 240 палестинцев. Обе стороны конфликта обвиняют в эскалации насилия друг друга.',
#   [(26, 35, 'NUMBER', 'B'),
#    (36, 47, 'NATIONALITY', 'B'),
#    (36, 47, 'NATIONALITY'),
#    (36, 47, 'NATIONALITY'),
#    (20, 25, 'EVENT'),
#    (20, 25, 'EVENT')]),
#  ('Витамин Б для Сочи от художника Кирилла Бородина',
#   [(14, 18, 'CITY', 'B'),
#    (22, 31, 'PROFESSION', 'B'),
#    (32, 48, 'PERSON', 'B'),
#    (0, 9, 'EVENT', 'B')]),
#  ('Кирилл Бородин', [(0, 14, 'PERSON', 'B')]),
#  ('15 декабря 2017 года в Сочинском художественном музее состоялось открытие персональной выставки художника Кирилла Бородина «Витамин Б».',
#   [(23, 27, 'CITY', 'B'),
#    (96, 105, 'PROFESSION', 'B'),
#    (106, 122, 'PERSON', 'B'),
#    (0, 20, 'DATE', 'B'),
#    (23, 32, 'CITY'),
#    (23, 53, 'ORGANIZATION'),
#    (65, 95, 'EVENT'),
#    (96, 105, 'PROFESSION'),
#    (106, 122, 'PERSON'),
#    (124, 133, 'EVENT'),
#    (74, 95, 'EVENT'),
#    (87, 95, 'EVENT'),
#    (124, 133, 'EVENT')]),
#  ('Совсем недавно Кириллу исполнилось 30 лет, но, несмотря на столь «юный» возраст, художник имеет впечатляющий список наград и достижений: после окончания Екатеринбургского художественного училища им. Шадра (отделение театральной живописи), а затем Уральской Государственной архитектурно-художественной академии он успел послужить художником - декоратором в Свердловском театре музыкальной комедии; стать членом Союза художников России, лауреатом областных всероссийских, международных выставок и творческих конкурсов. В 2016 году Союзом художников России Кирилл Бородин был делегирован в творческую командировку на Академическую дачу им. Репина. Будучи постоянным участником молодёжного образовательного форума Таврида, в том же году он был выбран в числе ещё 7 художников для встречи с президентом РФ Владимиром Путиным. В 2017 году его включили в так называемую Творческую команду России, в составе которой  он снова встречался с президентом. В 2017 году Кирилл представлял Свердловскую область на Всемирном Фестивале молодежи и студентов в Сочи.',
#   [(1042, 1046, 'CITY', 'B'),
#    (554, 568, 'PERSON'),
#    (35, 41, 'AGE'),
#    (153, 204, 'ORGANIZATION'),
#    (247, 309, 'ORGANIZATION'),
#    (329, 353, 'PROFESSION'),
#    (356, 395, 'ORGANIZATION'),
#    (410, 433, 'ORGANIZATION'),
#    (517, 528, 'DATE'),
#    (529, 553, 'ORGANIZATION'),
#    (614, 643, 'FACILITY'),
#    (710, 717, 'EVENT'),
#    (719, 732, 'DATE'),
#    (759, 760, 'NUMBER'),
#    (786, 797, 'PROFESSION'),
#    (801, 819, 'PERSON'),
#    (821, 832, 'DATE'),
#    (863, 888, 'ORGANIZATION'),
#    (786, 797, 'PROFESSION'),
#    (821, 832, 'DATE'),
#    (975, 995, 'STATE_OR_PROVINCE'),
#    (999, 1039, 'EVENT'),
#    (1042, 1046, 'CITY'),
#    (15, 22, 'PERSON'),
#    (81, 89, 'PROFESSION'),
#    (153, 170, 'CITY'),
#    (199, 204, 'PERSON'),
#    (206, 236, 'ORGANIZATION'),
#    (356, 368, 'CITY'),
#    (416, 426, 'PROFESSION'),
#    (427, 433, 'COUNTRY'),
#    (416, 426, 'PROFESSION'),
#    (427, 433, 'COUNTRY'),
#    (554, 568, 'PERSON'),
#    (637, 643, 'PERSON'),
#    (416, 426, 'PROFESSION'),
#    (786, 800, 'PROFESSION'),
#    (798, 800, 'COUNTRY'),
#    (427, 433, 'COUNTRY'),
#    (15, 21, 'PERSON'),
#    (247, 256, 'LOCATION'),
#    (573, 584, 'EVENT'),
#    (776, 783, 'EVENT')]),
#  ('Вернисаж  прошёл без особого пафоса, но присутствовали на нём не только представители СМИ, фотографы и просто любители живописи, но и «коллеги по цеху», галеристы.',
#   [(0, 8, 'EVENT', 'B'),
#    (91, 100, 'PROFESSION', 'B'),
#    (153, 162, 'PROFESSION', 'B')]),
#  ('В церемонии открытия участвовали: директор Художественного музея Пётр Хрисанов; Борис Салахов, государственный эксперт по культурным ценностям, заведующий выставочным отделом; Екатерина Хотинова, старший научный сотрудник сочинского Художественного музея.',
#   [(34, 64, 'PROFESSION', 'B'),
#    (65, 78, 'PERSON', 'B'),
#    (80, 93, 'PERSON', 'B'),
#    (95, 142, 'PROFESSION', 'B'),
#    (144, 174, 'PROFESSION', 'B'),
#    (176, 194, 'PERSON', 'B'),
#    (196, 221, 'PROFESSION', 'B'),
#    (222, 232, 'CITY', 'B'),
#    (222, 253, 'ORGANIZATION'),
#    (43, 64, 'ORGANIZATION'),
#    (95, 118, 'PROFESSION'),
#    (204, 221, 'PROFESSION'),
#    (2, 20, 'EVENT')]),
#  ('После официальной части все поднялись на третий этаж музея, где в самом большом зале расположена экспозиция.',
#   [(41, 47, 'ORDINAL', 'B')]),
#  ('Кирилл Бородин сказал:',
#   [(0, 14, 'PERSON', 'B'),
#    (0, 14, 'PERSON', 'B'),
#    (0, 14, 'PERSON', 'B'),
#    (0, 6, 'PERSON', 'B')]),
#  ('Для самого насыщенного яркими красками и витаминами города страны я подготовил выставку «Витамин Б». В экспозицию включены несколько живописных серий — можно будет увидеть часть работ из моего 4 месячного пленэра в Таиланде 2013 года, картины проекта «Китайское детство», которые я представлял на Уральской Биеннале современного искусства, анималистические работы и многие другие.',
#   [(89, 98, 'EVENT', 'B'),
#    (89, 98, 'EVENT'),
#    (193, 194, 'ORDINAL'),
#    (215, 223, 'COUNTRY'),
#    (252, 269, 'WORK_OF_ART'),
#    (297, 338, 'EVENT'),
#    (224, 233, 'DATE'),
#    (297, 306, 'LOCATION'),
#    (297, 306, 'LOCATION'),
#    (252, 261, 'COUNTRY'),
#    (89, 98, 'EVENT')]),
#  ('И действительно, представленные работы художника наполнили пространство зала настоящими витаминами жизнелюбия, юмора вперемежку с иронией, они буквально искрят озорством и позитивом.',
#   [(39, 48, 'PROFESSION', 'B'),
#    (39, 48, 'PROFESSION'),
#    (39, 47, 'PROFESSION'),
#    (39, 48, 'PROFESSION')]),
#  ('Любой желающий мог пообщаться и сфотографироваться с художником, получить ответы на интересующие вопросы.',
#   [(53, 61, 'PROFESSION', 'B'), (53, 63, 'PROFESSION')]),
#  ('Вход на вернисаж был свободным, ну а сама выставка будет длиться до 15 января.',
#   [(65, 77, 'DATE', 'B'), (8, 16, 'EVENT'), (42, 50, 'EVENT')]),
#  ('Суд Милана приговорил Сильвио Берлускони к четырём годам тюрьмы',
#   [(0, 10, 'ORGANIZATION', 'B'),
#    (22, 40, 'PERSON', 'B'),
#    (4, 10, 'CITY'),
#    (43, 63, 'PENALTY'),
#    (57, 63, 'PENALTY'),
#    (11, 21, 'EVENT'),
#    (43, 56, 'DATE')]),
#  ('Сильвио Берлускони.',
#   [(0, 18, 'PERSON', 'B'), (0, 18, 'PERSON', 'B'), (0, 18, 'PERSON', 'B')]),
#  ('Владимир Путин и Сильвио Берлускони.',
#   [(17, 35, 'PERSON', 'B'),
#    (17, 35, 'PERSON'),
#    (0, 14, 'PERSON'),
#    (17, 35, 'PERSON')]),
#  ('26 октября 2012 года суд Милана признал бывшего премьера Италии Сильвио Берлускони виновным в схемах по уклонению от уплаты налогов и приговорил его к четырём годам тюрьмы.',
#   [(64, 82, 'PERSON', 'B'),
#    (64, 82, 'PERSON'),
#    (64, 82, 'PERSON'),
#    (0, 20, 'DATE'),
#    (64, 82, 'PERSON'),
#    (25, 31, 'CITY'),
#    (151, 171, 'PENALTY'),
#    (165, 171, 'PENALTY'),
#    (21, 31, 'ORGANIZATION'),
#    (25, 31, 'CITY'),
#    (48, 63, 'PROFESSION'),
#    (48, 56, 'PROFESSION'),
#    (57, 63, 'COUNTRY'),
#    (104, 131, 'CRIME'),
#    (151, 171, 'PENALTY'),
#    (165, 171, 'PENALTY'),
#    (134, 144, 'EVENT'),
#    (151, 164, 'DATE'),
#    (151, 164, 'DATE'),
#    (134, 144, 'EVENT')]),
#  ('Кроме того, ему в течение трёх лет запрещено занимать государственные должности.',
#   [(16, 34, 'DATE', 'B'), (35, 79, 'PENALTY', 'B')]),
#  ('Бывший премьер Италии обвиняется в том, что в 1990-е годы неоднократно применял для ухода от уплаты налогов финансовую схему с использованием офшорной компании.',
#   [(44, 57, 'DATE', 'B'),
#    (7, 21, 'PROFESSION'),
#    (7, 14, 'PROFESSION'),
#    (15, 21, 'COUNTRY'),
#    (15, 21, 'COUNTRY'),
#    (84, 107, 'CRIME')]),
#  ('Так в 1994—1999 годах принадлежащая Берлускони компания Fininvest через посредников в офшорных зонах выкупила за 470 млн евро права на показ американских ТВ-каналов и фильмов и передала их дочерней компании Mediaset.',
#   [(6, 21, 'DATE', 'B'),
#    (36, 46, 'PERSON', 'B'),
#    (56, 65, 'ORGANIZATION', 'B'),
#    (113, 125, 'MONEY', 'B'),
#    (141, 153, 'COUNTRY', 'B'),
#    (207, 215, 'ORGANIZATION', 'B')]),
#  ('По мнению прокуратуры конечная цена была завышена для уменьшения налогооблагаемой базы в Италии, причём разница оседала в оффшорных фондах связанных с Берлускони.',
#   [(151, 161, 'PERSON', 'B'),
#    (89, 95, 'COUNTRY'),
#    (151, 161, 'PERSON'),
#    (89, 95, 'COUNTRY'),
#    (89, 95, 'COUNTRY'),
#    (10, 21, 'ORGANIZATION')]),
#  ('Прокуратура требовала для бывшего главы государства наказания в виде лишения свободы на 3 года и 8 месяцев.',
#   [(34, 51, 'PROFESSION', 'B'),
#    (0, 11, 'ORGANIZATION', 'B'),
#    (69, 106, 'PENALTY'),
#    (85, 106, 'DATE'),
#    (69, 84, 'PENALTY')]),
#  ('Однако суд назначил наказание выше требуемого.', []),
#  ('Через несколько часов после первых сообщений ленты новостных агентств облетело следующее срочное сообщение.',
#   [(0, 21, 'TIME', 'B')]),
#  ('В соответствии с принятой левоцентристским правительством Романо Проди в 2006 году амнистией, принятой с целью обезопасить тюрьмы от переполнения, срок Сильвио Берлускони может быть сокращён до одного года.',
#   [(152, 170, 'PERSON', 'B'),
#    (152, 170, 'PERSON'),
#    (152, 170, 'PERSON'),
#    (152, 170, 'PERSON'),
#    (160, 170, 'PERSON'),
#    (160, 170, 'PERSON'),
#    (58, 70, 'PERSON'),
#    (71, 82, 'DATE'),
#    (152, 170, 'PERSON'),
#    (123, 129, 'PENALTY'),
#    (123, 129, 'PENALTY'),
#    (26, 42, 'IDEOLOGY'),
#    (43, 57, 'ORGANIZATION'),
#    (43, 70, 'ORGANIZATION'),
#    (83, 92, 'EVENT'),
#    (191, 205, 'DATE')]),
#  ('Адвокаты предпринимателя пока не комментируют решение суда.',
#   [(0, 8, 'PROFESSION', 'B'),
#    (9, 24, 'PROFESSION', 'B'),
#    (0, 24, 'PROFESSION', 'B')]),
#  ('Интересно, что вчера 76-летний бывший премьер-министр Италии и лидер главной партии правого центра «Народ свободы» окончательно объявил о своем уходе с политической арены.',
#   [(54, 60, 'COUNTRY', 'B'),
#    (15, 20, 'DATE'),
#    (21, 30, 'AGE'),
#    (100, 113, 'ORGANIZATION'),
#    (38, 45, 'PROFESSION'),
#    (38, 60, 'PROFESSION'),
#    (38, 53, 'PROFESSION'),
#    (63, 113, 'PROFESSION'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (54, 60, 'COUNTRY'),
#    (84, 98, 'IDEOLOGY')]),
#  ('В частности он заявил:', []),
#  (' Из любви к Италии можно совершать безумства и делать мудрые вещи 19 лет назад я начал политическую карьеру Это было безумством не лишенным мудрости Сейчас предпочитаю сделать шаг назад по тем же причинам и соображениям которые двигали мной в 1994 году Но у меня еще есть мускулы и мысли и я готов давать советы делиться опытом ',
#   [(12, 18, 'COUNTRY', 'B'),
#    (12, 18, 'COUNTRY'),
#    (66, 78, 'DATE'),
#    (241, 252, 'DATE'),
#    (12, 18, 'COUNTRY'),
#    (12, 18, 'COUNTRY'),
#    (12, 18, 'COUNTRY')]),
#  ('Интересно, что СМИ в связи с приговором Сильвио Берлускони вспоминали его тёплую дружбу с бессменным главой России Владимиром Путиным.',
#   [(40, 58, 'PERSON', 'B'),
#    (40, 58, 'PERSON'),
#    (40, 58, 'PERSON'),
#    (40, 58, 'PERSON'),
#    (48, 58, 'PERSON'),
#    (48, 58, 'PERSON'),
#    (40, 58, 'PERSON'),
#    (40, 58, 'PERSON'),
#    (115, 133, 'PERSON'),
#    (101, 114, 'PROFESSION'),
#    (108, 114, 'COUNTRY')]),
#  ("Итальянская пресса отмечает: ''«на протяжении долгой истории этих особых отношений Берлускони и Путин занимали различные государственные должности, но всегда находили повод для встреч: они советовались друг с другом, в их отношениях была гармония вне зависимости от официальных обязанностей или вызывающих подозрение личных мотивов»''.",
#   [(83, 93, 'PERSON', 'B'),
#    (83, 93, 'PERSON'),
#    (0, 11, 'COUNTRY'),
#    (83, 93, 'PERSON'),
#    (96, 101, 'PERSON')]),
#  ('Папа Бенедикт XVI назначил новых кардиналов',
#   [(0, 4, 'PROFESSION', 'B'),
#    (5, 17, 'PERSON', 'B'),
#    (14, 17, 'ORDINAL', 'B'),
#    (33, 43, 'PROFESSION', 'B'),
#    (18, 26, 'EVENT')]),
#  ('Папа Римский Бенедикт XVI.',
#   [(0, 4, 'PROFESSION', 'B'),
#    (0, 4, 'PROFESSION', 'B'),
#    (13, 25, 'PERSON', 'B'),
#    (22, 25, 'ORDINAL', 'B'),
#    (0, 12, 'PROFESSION', 'B'),
#    (13, 25, 'PERSON'),
#    (22, 25, 'ORDINAL'),
#    (5, 12, 'CITY')]),
#  ('Облачение кардиналов.',
#   [(10, 20, 'PROFESSION', 'B'), (10, 20, 'PROFESSION')]),
#  ('Папа Римский Бенедикт XVI назначил шесть новых кардиналов.',
#   [(0, 4, 'PROFESSION', 'B'),
#    (0, 4, 'PROFESSION', 'B'),
#    (0, 4, 'PROFESSION', 'B'),
#    (35, 40, 'NUMBER'),
#    (13, 25, 'PERSON'),
#    (22, 25, 'ORDINAL'),
#    (47, 57, 'PROFESSION'),
#    (0, 12, 'PROFESSION'),
#    (47, 57, 'PROFESSION'),
#    (0, 12, 'PROFESSION'),
#    (47, 57, 'PROFESSION'),
#    (13, 25, 'PERSON'),
#    (22, 25, 'ORDINAL'),
#    (13, 25, 'PERSON'),
#    (22, 25, 'ORDINAL'),
#    (5, 12, 'CITY'),
#    (5, 12, 'CITY'),
#    (26, 34, 'EVENT'),
#    (26, 34, 'EVENT')]),
#  ('Все они — не из Европы, кардинальские шапки получили иерархи из Колумбии, Индии, Ливана, Нигерии, Филиппин и США.',
#   [(16, 22, 'LOCATION', 'B'),
#    (64, 72, 'COUNTRY', 'B'),
#    (74, 79, 'COUNTRY', 'B'),
#    (81, 87, 'COUNTRY', 'B'),
#    (89, 96, 'COUNTRY', 'B'),
#    (98, 106, 'COUNTRY', 'B'),
#    (109, 112, 'COUNTRY', 'B'),
#    (24, 37, 'PROFESSION'),
#    (53, 60, 'PROFESSION')]),
#  ('Пурпурные шапочки «князей Церкви», символизирующие готовность высших лиц церкви пролить свою кровь за её дело и золотые кардинальские перстни получили влиятельный сановник Римской курии, префект Папского дома архиепископ Джеймс Майкл Харви (США), маронитский патриарх Бeшара Бутрос ар-Раи (Ливан), сиро-маланкарский архиепископ Тривандрума Базелиос Клеемис Тоттункал (Индия), архиепископ Абуджи Джон Олорунфеми Онайекан (Нигерия), архиепископ Боготы Хесус Рубен Салазар Гомес (Колумбия) и архиепископ Манилы Луис Антонио Тагле (Филиппины).',
#   [(528, 536, 'COUNTRY', 'B'),
#    (241, 244, 'COUNTRY'),
#    (172, 185, 'ORGANIZATION'),
#    (187, 194, 'PROFESSION'),
#    (209, 220, 'PROFESSION'),
#    (221, 239, 'PERSON'),
#    (241, 244, 'COUNTRY'),
#    (268, 288, 'PERSON'),
#    (290, 295, 'COUNTRY'),
#    (368, 373, 'COUNTRY'),
#    (209, 220, 'PROFESSION'),
#    (421, 428, 'COUNTRY'),
#    (209, 220, 'PROFESSION'),
#    (450, 475, 'PERSON'),
#    (477, 485, 'COUNTRY'),
#    (209, 220, 'PROFESSION'),
#    (508, 526, 'PERSON'),
#    (528, 537, 'COUNTRY'),
#    (120, 133, 'PROFESSION'),
#    (19, 32, 'PROFESSION'),
#    (120, 133, 'PROFESSION'),
#    (187, 208, 'PROFESSION'),
#    (247, 267, 'PROFESSION'),
#    (298, 327, 'PROFESSION'),
#    (26, 32, 'ORGANIZATION'),
#    (195, 208, 'ORGANIZATION'),
#    (247, 258, 'ORGANIZATION'),
#    (298, 315, 'ORGANIZATION'),
#    (209, 220, 'PROFESSION'),
#    (259, 267, 'PROFESSION'),
#    (328, 366, 'PERSON'),
#    (388, 419, 'PERSON'),
#    (443, 449, 'CITY'),
#    (431, 449, 'PROFESSION'),
#    (501, 507, 'CITY'),
#    (489, 507, 'PROFESSION'),
#    (172, 179, 'CITY')]),
#  ('В ходе прошедшей в субботу церемонии Папа подчеркнул универсальность Католической церкви, напомнив о том, что это церковь всех людей, всех народов и «которая поет единую гармоничную песнь по имя Господа».',
#   [(37, 41, 'PROFESSION', 'B'),
#    (37, 41, 'PROFESSION'),
#    (37, 41, 'PROFESSION'),
#    (17, 26, 'DATE'),
#    (69, 88, 'ORGANIZATION'),
#    (37, 41, 'PROFESSION'),
#    (27, 36, 'EVENT'),
#    (69, 81, 'RELIGION'),
#    (195, 202, 'PERSON')]),
#  ('Назначение новых членов Курии прошло после того, как ряд критиков выразили обеспокоенность тем, что большинство кардиналов, которые будут выбирать нового Папу, представляют Европу.',
#   [(173, 179, 'LOCATION', 'B'),
#    (112, 122, 'PROFESSION'),
#    (112, 122, 'PROFESSION'),
#    (112, 122, 'PROFESSION'),
#    (17, 29, 'PROFESSION'),
#    (112, 122, 'PROFESSION'),
#    (154, 158, 'PROFESSION'),
#    (24, 29, 'ORGANIZATION')]),
#  ('Всего в Коллегию кардиналов входят представители из 66 государств мира, 116 из них не достигли 80-летнего возраста, то есть имеют право избирать Папу.',
#   [(8, 27, 'ORGANIZATION', 'B'),
#    (52, 54, 'NUMBER', 'B'),
#    (72, 75, 'NUMBER', 'B'),
#    (95, 105, 'AGE', 'B'),
#    (17, 27, 'PROFESSION'),
#    (17, 27, 'PROFESSION'),
#    (17, 27, 'PROFESSION'),
#    (17, 27, 'PROFESSION'),
#    (145, 149, 'PROFESSION'),
#    (17, 27, 'PROFESSION'),
#    (145, 149, 'PROFESSION')]),
#  ('В последний раз 85-ти летний Папа назначил 22 кардиналов в феврале — подавляющее большинство из них были европейские архиепископы и представители ватиканской бюрократии.',
#   [(29, 33, 'PROFESSION', 'B'),
#    (29, 33, 'PROFESSION'),
#    (29, 33, 'PROFESSION'),
#    (117, 128, 'PROFESSION'),
#    (117, 128, 'PROFESSION'),
#    (117, 128, 'PROFESSION'),
#    (117, 128, 'PROFESSION'),
#    (16, 28, 'AGE'),
#    (43, 45, 'NUMBER'),
# ...
#    (191, 197, 'COUNTRY'),
#    (157, 183, 'IDEOLOGY'),
#    (157, 190, 'ORGANIZATION'),
#    (75, 94, 'ORGANIZATION')]),
#  ('Электрик руководит социал-демократами Дюссельдорфа',
#   [(0, 8, 'PROFESSION', 'B'),
#    (38, 50, 'CITY', 'B'),
#    (19, 37, 'ORGANIZATION')]),
#  ('Партийный символ СдПГ', [(17, 21, 'ORGANIZATION', 'B')]),
#  ('В субботний полдень 9 апреля в Дюссельдорфе состоялись выборы нового городского председателя социал-демократической партии (СдПГ). Им совершенно неожиданно стал 48-летний Андреас Римкус (Andreas Rimkus), — электрик, представитель рабочего класса города . Причём за него проголосовало абсолютное большинство партийных делегатов выборщиков — 157 из 172 (8 воздержавшихся, 7 — против). В процентном отношении этот показатель составляет 91,3, что является самым лучшим показателем монолитности партии социал-демократов в Дюссельдорфе за последние годы.',
#   [(124, 128, 'ORGANIZATION', 'B'),
#    (0, 28, 'TIME', 'B'),
#    (20, 28, 'DATE'),
#    (31, 43, 'CITY'),
#    (93, 122, 'ORGANIZATION'),
#    (124, 128, 'ORGANIZATION'),
#    (161, 170, 'AGE'),
#    (171, 185, 'PERSON'),
#    (187, 201, 'PERSON'),
#    (206, 214, 'PROFESSION'),
#    (340, 343, 'NUMBER'),
#    (347, 350, 'NUMBER'),
#    (162, 163, 'NUMBER'),
#    (342, 343, 'NUMBER'),
#    (433, 437, 'NUMBER'),
#    (490, 514, 'ORGANIZATION'),
#    (31, 43, 'CITY'),
#    (533, 547, 'DATE'),
#    (55, 61, 'EVENT'),
#    (93, 115, 'IDEOLOGY'),
#    (497, 514, 'IDEOLOGY'),
#    (69, 122, 'PROFESSION')]),
#  ('Удивительно, но ещё в пятницу утром делегаты предстоящего партийного съезда не знали, за кого им голосовать. Дело в том, что предшествовавшие четыре года партийной организацией Дюссельдорфа руководила известный в Германии политик Карин Кортманн, — член бундестага и, одновременно, вице-президент Центрального комитета немецких католиков. Всё шло к тому, что она идёт к переизбранию на второй срок. И, действительно, Кортманн выдвинула свою кандидатуру.',
#   [(20, 29, 'DATE', 'B'),
#    (20, 35, 'TIME'),
#    (58, 75, 'EVENT'),
#    (142, 153, 'DATE'),
#    (177, 189, 'CITY'),
#    (213, 221, 'COUNTRY'),
#    (230, 244, 'PERSON'),
#    (248, 263, 'PROFESSION'),
#    (281, 336, 'PROFESSION'),
#    (385, 391, 'ORDINAL'),
#    (236, 244, 'PERSON'),
#    (177, 189, 'CITY'),
#    (222, 229, 'PROFESSION'),
#    (253, 263, 'ORGANIZATION'),
#    (296, 336, 'ORGANIZATION'),
#    (318, 326, 'COUNTRY'),
#    (327, 336, 'RELIGION'),
#    (69, 75, 'EVENT')]),
#  ('Но нее тут-то было. В своей яркой речи против Кортманн выступила ещё одна крупная партийная фигура Дюссельдорфа и Германии — Юрген Бюссов (бывший педагог, активный партийный функционер Дюссельдорской ячейки СдПГ, состоявший с 1995 по 2010 год начальником (президентом) крупного округа Дюссельдорф). Нашла коса на камень, партийной организации социал-демократов столицы Северного-Рейна Вестфалии стал грозить раскол. Взвесив все факты за и против, Карин Кортманн взяла самоотвод и сообщила об этом в Дюссельдорф из Берлина, где она участвовала в конференции немецких католиков, переживающих не самые лучшие времена. Она призвала партийных лидеров отдать свои голоса за своего заместителя Андреаса Римкуса. Причём просила сделать это единогласно.',
#   [(207, 211, 'ORGANIZATION', 'B'),
#    (207, 211, 'ORGANIZATION'),
#    (99, 111, 'CITY'),
#    (114, 122, 'COUNTRY'),
#    (447, 461, 'PERSON'),
#    (46, 54, 'PERSON'),
#    (46, 54, 'PERSON'),
#    (99, 111, 'CITY'),
#    (114, 122, 'COUNTRY'),
#    (125, 137, 'PERSON'),
#    (146, 153, 'PROFESSION'),
#    (164, 184, 'PROFESSION'),
#    (207, 211, 'ORGANIZATION'),
#    (224, 242, 'DATE'),
#    (243, 254, 'PROFESSION'),
#    (99, 110, 'CITY'),
#    (321, 360, 'ORGANIZATION'),
#    (369, 394, 'STATE_OR_PROVINCE'),
#    (447, 461, 'PERSON'),
#    (99, 110, 'CITY'),
#    (514, 521, 'CITY'),
#    (545, 556, 'EVENT'),
#    (675, 686, 'PROFESSION'),
#    (687, 703, 'PERSON'),
#    (99, 111, 'CITY'),
#    (343, 360, 'IDEOLOGY'),
#    (557, 565, 'COUNTRY'),
#    (566, 575, 'RELIGION'),
#    (185, 199, 'CITY'),
#    (185, 211, 'ORGANIZATION'),
#    (361, 394, 'CITY'),
#    (545, 575, 'EVENT'),
#    (468, 477, 'EVENT'),
#    (256, 267, 'PROFESSION')]),
#  ('Практически одновременно самоотвод подал и Юрген Бюссов, посчитав, что добился своего и также выразив поддержку Римкусу. Таким образом, только в пятницу 8 апреля дорога для Андреаса Римкуса была открыта и он согласился избираться на место председателя местного партийного отделения, хотя до этого твёрдо стоял на позиции неучастия в выборах в качестве кандидата, считая, что негоже делать это в противовес Карин Кортманн.',
#   [(153, 154, 'NUMBER', 'B'),
#    (143, 152, 'DATE'),
#    (406, 420, 'PERSON'),
#    (412, 420, 'PERSON'),
#    (412, 420, 'PERSON'),
#    (43, 55, 'PERSON'),
#    (406, 420, 'PERSON'),
#    (173, 189, 'PERSON'),
#    (43, 55, 'PERSON'),
#    (112, 119, 'PERSON'),
#    (143, 161, 'DATE'),
#    (173, 189, 'PERSON'),
#    (239, 281, 'PROFESSION'),
#    (406, 420, 'PERSON'),
#    (252, 281, 'ORGANIZATION'),
#    (25, 34, 'EVENT'),
#    (25, 34, 'EVENT')]),
#  ('Результаты выборов порадовали социал-демократов и самого Римкуса. Он увидел в результатах голосования укрепление партийной дисциплины и намерен противостоять политике местного отделения христианских демократов (ХДС), которые, по мнению СдПГ, стоят на защите крупного капитала, а не простых людей.',
#   [(236, 240, 'ORGANIZATION', 'B'),
#    (236, 240, 'ORGANIZATION'),
#    (236, 240, 'ORGANIZATION'),
#    (57, 64, 'PERSON'),
#    (211, 214, 'ORGANIZATION'),
#    (236, 240, 'ORGANIZATION'),
#    (30, 47, 'IDEOLOGY'),
#    (158, 165, 'PROFESSION'),
#    (30, 47, 'ORGANIZATION'),
#    (186, 198, 'RELIGION'),
#    (186, 209, 'IDEOLOGY')]),
#  ('Байден беседовал с президентом Эквадора о Сноудене',
#   [(0, 6, 'PERSON', 'B'),
#    (19, 30, 'PROFESSION', 'B'),
#    (42, 50, 'PERSON', 'B'),
#    (19, 39, 'PROFESSION'),
#    (31, 39, 'COUNTRY'),
#    (7, 16, 'EVENT')]),
#  (' Джо Байден в окружении военнослужащих США Рафаэль Корреа Эдвард Сноуден ',
#   [(5, 11, 'PERSON', 'B'),
#    (1, 11, 'PERSON'),
#    (43, 57, 'PERSON'),
#    (58, 72, 'PERSON'),
#    (24, 42, 'PROFESSION'),
#    (24, 38, 'PROFESSION'),
#    (39, 42, 'COUNTRY')]),
#  ('Вице-президент США Джо Байден побеседовал с президентом Эквадора Рафаэлем Корреа по поводу Эдварда Сноудена.',
#   [(23, 29, 'PERSON', 'B'),
#    (44, 55, 'PROFESSION', 'B'),
#    (19, 29, 'PERSON'),
#    (0, 14, 'PROFESSION'),
#    (19, 29, 'PERSON'),
#    (44, 55, 'PROFESSION'),
#    (65, 80, 'PERSON'),
#    (91, 107, 'PERSON'),
#    (44, 64, 'PROFESSION'),
#    (56, 64, 'COUNTRY'),
#    (15, 18, 'COUNTRY'),
#    (0, 18, 'PROFESSION'),
#    (15, 18, 'COUNTRY'),
#    (44, 64, 'PROFESSION'),
#    (56, 64, 'COUNTRY'),
#    (32, 41, 'EVENT'),
#    (30, 41, 'EVENT')]),
#  ('Байден просил отказать Сноудену в предоставлении убежища, которое Сноуден предположительно, хочет получить.',
#   [(0, 6, 'PERSON', 'B'),
#    (0, 6, 'PERSON', 'B'),
#    (23, 31, 'PERSON', 'B'),
#    (23, 30, 'PERSON')]),
#  ('Корреа в ответ заявил, что судьба Сноудена находится в российских руках.',
#   [(34, 41, 'PERSON', 'B'),
#    (0, 6, 'PERSON', 'B'),
#    (34, 42, 'PERSON'),
#    (55, 65, 'COUNTRY')]),
#  ('О разговоре с Байденом рассказал сам Корреа во время еженедельного обращения к эквадорцам.',
#   [(14, 20, 'PERSON', 'B'),
#    (14, 20, 'PERSON'),
#    (37, 43, 'PERSON'),
#    (14, 22, 'PERSON'),
#    (37, 43, 'PERSON'),
#    (79, 89, 'NATIONALITY'),
#    (53, 66, 'DATE'),
#    (2, 11, 'EVENT')]),
#  ('По его словам, беседа состоялась в пятницу.',
#   [(35, 42, 'DATE', 'B'), (15, 21, 'EVENT')]),
#  ('Белый дом подтверждает факт разговора о Сноудене, однако ничего не сообщает о деталях или результатах этого общения.',
#   [(40, 48, 'PERSON', 'B'),
#    (40, 47, 'PERSON'),
#    (0, 9, 'ORGANIZATION'),
#    (40, 48, 'PERSON'),
#    (28, 37, 'EVENT')]),
#  ('Власти Эквадора заявили, что не могут рассмотреть вопрос о предоставлении убежища Сноудену до тех пор, пока он не окажется на территории страны.',
#   [(82, 90, 'PERSON', 'B'),
#    (82, 89, 'PERSON'),
#    (7, 15, 'COUNTRY'),
#    (82, 90, 'PERSON'),
#    (7, 15, 'COUNTRY'),
#    (7, 15, 'COUNTRY'),
#    (0, 15, 'ORGANIZATION')]),
#  ('Предполагается, что Эдвард Сноуден, разгласивший секретную информацию об американских программах по борьбе с терроризмом, по-прежнему находится в транзитной зоне московского аэропорта Шереметьево, куда он прилетел из Гонконга с намерением добраться до Эквадора через Кубу.',
#   [(20, 34, 'PERSON', 'B'),
#    (27, 34, 'PERSON', 'B'),
#    (252, 260, 'COUNTRY', 'B'),
#    (20, 34, 'PERSON'),
#    (73, 85, 'COUNTRY'),
#    (162, 173, 'CITY'),
#    (184, 195, 'FACILITY'),
#    (217, 225, 'STATE_OR_PROVINCE'),
#    (252, 260, 'COUNTRY'),
#    (267, 271, 'COUNTRY'),
#    (252, 260, 'COUNTRY'),
#    (252, 260, 'COUNTRY'),
#    (109, 120, 'CRIME')]),
#  ('Его американский паспорт аннулирован, и США добиваются выдачи Сноудена.',
#   [(62, 69, 'PERSON', 'B'),
#    (62, 70, 'PERSON'),
#    (4, 16, 'COUNTRY'),
#    (40, 43, 'COUNTRY'),
#    (62, 70, 'PERSON'),
#    (40, 43, 'COUNTRY'),
#    (40, 43, 'COUNTRY'),
#    (17, 37, 'EVENT')]),
#  ('Ранее Эквадор предоставил убежище основателю WikiLeaks Джулиану Ассанжу, который остаётся в посольстве Эквадора в Лондоне.',
#   [(103, 111, 'COUNTRY', 'B'),
#    (103, 111, 'COUNTRY'),
#    (6, 13, 'COUNTRY'),
#    (55, 71, 'PERSON'),
#    (92, 111, 'ORGANIZATION'),
#    (114, 121, 'CITY'),
#    (103, 111, 'COUNTRY'),
#    (103, 111, 'COUNTRY'),
#    (45, 54, 'ORGANIZATION'),
#    (103, 111, 'COUNTRY'),
#    (14, 33, 'EVENT')]),
#  ('Президент Корреа заявлял, что США должны не ловить Сноудена, а объясниться по поводу секретных программ, предполагающих сбор информации о телефонных звонках и электронной переписке американцев.',
#   [(51, 58, 'PERSON', 'B'),
#    (10, 16, 'PERSON'),
#    (51, 59, 'PERSON'),
#    (10, 16, 'PERSON'),
#    (30, 33, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (0, 9, 'PROFESSION'),
#    (30, 33, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (181, 192, 'NATIONALITY'),
#    (30, 33, 'COUNTRY'),
#    (30, 33, 'COUNTRY'),
#    (10, 16, 'PERSON')]),
#  ('Кроме того, президент Эквадора сообщил, что судьба Сноудена находится в российских руках.',
#   [(51, 58, 'PERSON', 'B'),
#    (51, 59, 'PERSON'),
#    (72, 82, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (22, 29, 'COUNTRY'),
#    (51, 59, 'PERSON'),
#    (12, 21, 'PROFESSION'),
#    (51, 59, 'PERSON'),
#    (72, 82, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (22, 30, 'COUNTRY'),
#    (12, 30, 'PROFESSION'),
#    (22, 30, 'COUNTRY')]),
#  ('Тем временем американские СМИ начали информационную войну, направленную на то, чтобы не допустить получение Сноуденом убежища в Эквадоре.',
#   [(108, 115, 'PERSON', 'B'),
#    (128, 135, 'COUNTRY', 'B'),
#    (13, 25, 'COUNTRY'),
#    (108, 117, 'PERSON'),
#    (128, 136, 'COUNTRY')]),
#  ('Например, по сообщению агентства Associated Press, жители Эквадора, которые разводят розы и дельфинии, жалуются на то, что из-за Сноудена американское правительство отказалось снизить тарифы на импорт роз из их страны.',
#   [(129, 136, 'PERSON', 'B'),
#    (129, 137, 'PERSON'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (58, 65, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (129, 137, 'PERSON'),
#    (33, 49, 'ORGANIZATION'),
#    (58, 66, 'COUNTRY'),
#    (129, 137, 'PERSON'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (58, 66, 'COUNTRY'),
#    (138, 150, 'COUNTRY'),
#    (138, 164, 'ORGANIZATION')]),
#  ('Хозяин крупной плантации Джино Дескальси:', [(25, 40, 'PERSON', 'B')]),
#  ('Мы просто шокированы случившимся. Придётся менять все планы на ближайший год.  Почему мы должны зависеть от какого-то 29 летнего хакера, которого мы даже не знаем.',
#   [(60, 76, 'DATE', 'B'),
#    (118, 128, 'AGE', 'B'),
#    (129, 135, 'PROFESSION', 'B')]),
#  ('СМИ отмечают, что предоставление статуса беженца «хакеру» нанесёт серьёзный ущерб по благосостоянию 50 тысяч человек, занимающихся выращиванием цветов, а эта отрасль экономики — четвёртая по важности в стране после нефти, морепродуктов и бананов.',
#   [(100, 108, 'NUMBER', 'B'),
#    (178, 187, 'ORDINAL', 'B'),
#    (50, 56, 'PROFESSION')]),
#  ('«Союз» впервые пристыковался к МКС за 6 часов',
#   [(1, 5, 'PRODUCT', 'B'),
#    (31, 34, 'FACILITY', 'B'),
#    (35, 45, 'TIME', 'B'),
#    (15, 28, 'EVENT')]),
#  ('29 марта 2013 года в 0:43 мск пилотируемый корабль «Союз ТМА-08М» стартовал с космодрома Байконур к Международной космической станции (МКС) и впервые в истории уже через 6 часов в 06:28:22 пристыковался к малому исследовательскому модулю «Поиск» российского сегмента МКС.',
#   [(52, 56, 'PRODUCT', 'B'),
#    (135, 138, 'FACILITY', 'B'),
#    (0, 18, 'DATE', 'B'),
#    (0, 29, 'TIME', 'B'),
#    (52, 64, 'PRODUCT'),
#    (89, 97, 'FACILITY'),
#    (100, 133, 'FACILITY'),
#    (135, 138, 'FACILITY'),
#    (164, 177, 'TIME'),
#    (239, 244, 'FACILITY'),
#    (246, 257, 'COUNTRY'),
#    (135, 138, 'FACILITY'),
#    (66, 75, 'EVENT'),
#    (178, 188, 'TIME'),
#    (164, 188, 'TIME'),
#    (189, 202, 'EVENT'),
#    (189, 202, 'EVENT')]),
#  ('Новому экипажу, в составе которого двое россиян — Павел Виноградов и Александр Мисуркин и одни американец — Кристофер Кэссиди, предстоит проработать на околоземной орбите больше 4 месяцев. Командир экипажа Павел Виноградов 31 августа 2013 года встретит в космосе своё 60-летие, и для него это уже третий космический полёт.',
#   [(35, 39, 'NUMBER', 'B'),
#    (40, 47, 'NATIONALITY', 'B'),
#    (50, 66, 'PERSON', 'B'),
#    (69, 87, 'PERSON', 'B'),
#    (90, 94, 'NUMBER', 'B'),
#    (95, 105, 'NATIONALITY', 'B'),
#    (108, 125, 'PERSON', 'B'),
#    (171, 187, 'DATE', 'B'),
#    (50, 66, 'PERSON'),
#    (223, 238, 'DATE'),
#    (268, 276, 'AGE'),
#    (297, 303, 'ORDINAL'),
#    (189, 205, 'PROFESSION'),
#    (304, 321, 'EVENT')]),
#  ('На борту МКС прибывших космонавтов встретили члены экспедиции «Союз ТМА-07М»: командир экипажа канадец Кристофер Хэдфилд, россиянин Роман Романенко и американец Томас Маршбёрн.',
#   [(63, 67, 'PRODUCT', 'B'),
#    (9, 12, 'FACILITY'),
#    (9, 12, 'FACILITY'),
#    (122, 129, 'NATIONALITY'),
#    (150, 160, 'NATIONALITY'),
#    (63, 75, 'PRODUCT'),
#    (95, 102, 'NATIONALITY'),
#    (103, 120, 'PERSON'),
#    (122, 131, 'NATIONALITY'),
#    (132, 147, 'PERSON'),
#    (150, 160, 'NATIONALITY'),
#    (161, 175, 'PERSON'),
#    (9, 12, 'FACILITY'),
#    (9, 12, 'FACILITY'),
#    (23, 34, 'PROFESSION'),
#    (78, 94, 'PROFESSION'),
#    (51, 75, 'ORGANIZATION')]),
#  ('В ходе работы экспедиции запланирована 50 экспериментов: 48 экспериментов начаты в предыдущих экспедициях, 2 эксперимента являются новыми.',
#   [(39, 41, 'NUMBER', 'B'),
#    (57, 59, 'NUMBER', 'B'),
#    (107, 108, 'NUMBER', 'B')]),
#  ('Специалисты отмечают тот факт, что в истории МКС это — первый полёт пилотируемого корабля к станции по укороченной, 6-часовой схеме. Ранее процесс подготовки к стыковке занимал порядка двух суток.',
#   [(45, 48, 'FACILITY', 'B'),
#    (45, 48, 'FACILITY'),
#    (55, 61, 'ORDINAL'),
#    (116, 125, 'TIME'),
#    (177, 195, 'DATE'),
#    (45, 48, 'FACILITY'),
#    (45, 48, 'FACILITY'),
#    (45, 48, 'FACILITY')]),
#  ('«Одно из главных преимуществ полета по шестичасовой, укороченной схеме заключается в том, что экипаж не успевает почувствовать невесомость сразу, поскольку влияние невесомости на организм начинает сказываться примерно после пяти часов полета», — эти слова командира корабля «Союз ТМА-08М» Павла Виноградова, сказанные им накануне полета, цитирует в пятницу ИТАР-ТАСС.',
#   [(275, 279, 'PRODUCT', 'B'),
#    (275, 287, 'PRODUCT'),
#    (39, 51, 'TIME'),
#    (209, 234, 'TIME'),
#    (275, 287, 'PRODUCT'),
#    (289, 306, 'PERSON'),
#    (347, 356, 'DATE'),
#    (357, 366, 'ORGANIZATION'),
#    (256, 273, 'PROFESSION'),
#    (256, 287, 'PROFESSION')]),
#  ('Кроме того, как отмечает агентство, другим плюсом укороченной схемы стыковки, является быстрая доставка на станцию скоропортящихся биоэлементов.',
#   []),
#  ('«Квадрат» получил «Золотую пальмовую ветвь» Каннского кинофестиваля 2017',
#   [(1, 8, 'WORK_OF_ART', 'B'), (44, 67, 'EVENT', 'B')]),
#  ('Рубен Эстлунд', [(0, 13, 'PERSON', 'B')]),
#  ('«Золотую пальмовую ветвь» Каннского кинофестиваля 2017 года получила драма шведского режиссёра Рубена Эстлунда «Квадрат».',
#   [(112, 119, 'WORK_OF_ART', 'B'),
#    (26, 49, 'EVENT'),
#    (26, 49, 'EVENT'),
#    (50, 54, 'DATE'),
#    (75, 84, 'NATIONALITY'),
#    (95, 110, 'PERSON'),
#    (112, 119, 'WORK_OF_ART')]),
#  ('Робен Кампийо', [(0, 13, 'PERSON', 'B')]),
#  ...]

# %%
import torch
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import Trainer, TrainingArguments

def convert_to_bio_format(data):
    new_data = []
    for text, annotations in data:
        entities = sorted(annotations, key=lambda x: x[0])
        bio_labels = ["O"] * len(text)

        for entity in entities:
            start, end, label = entity[:3]

            bio_labels[start] = f"B-{label}"
            for i in range(start + 1, end):
                bio_labels[i] = f"I-{label}"

        new_data.append({"text": list(text), "labels": bio_labels})

    return new_data


# Prepare the dataset
class NERDataset(Dataset):
    def __init__(self, data, tokenizer, max_len=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
      item = self.data[idx]
      text = item["text"]
      labels = item["labels"]
  
      encoding = self.tokenizer.encode_plus(
          text,
          truncation=True,
          max_length=self.max_len,
          padding="max_length",
          is_split_into_words=True,
          return_tensors="pt",
      )
  
      label_ids = [self.tokenizer.convert_tokens_to_ids(label) for label in labels]
      label_ids = label_ids[:self.max_len]  # Truncate labels if needed
      label_ids_padded = label_ids + [0] * (self.max_len - len(label_ids))
  
      return {
          "input_ids": encoding["input_ids"].squeeze(),
          "attention_mask": encoding["attention_mask"].squeeze(),
          "labels": torch.tensor(label_ids_padded, dtype=torch.long),
      }



        

train_data = convert_to_bio_format(dataset)

# Assuming that 80% of the data is used for training and 20% for validation
train_len = int(0.8 * len(train_data))
val_len = len(train_data) - train_len

train_dataset = NERDataset(train_data[:train_len], tokenizer)
val_dataset = NERDataset(train_data[train_len:], tokenizer)

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs",
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# Train the model
trainer.train()

# Save the model
trainer.save_model("./ner_xlm_roberta")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-184d81b2dbfd> in <cell line: 91>()
#      89
#      90 # Train the model
# ---> 91 trainer.train()
#      92
#      93 # Save the model
#
# /usr/local/lib/python3.9/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1660             self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1661         )
# -> 1662         return inner_training_loop(
#    1663             args=args,
#    1664             resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.9/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1927                         tr_loss_step = self.training_step(model, inputs)
#    1928                 else:
# -> 1929                     tr_loss_step = self.training_step(model, inputs)
#    1930
#    1931                 if (
#
# /usr/local/lib/python3.9/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2697
#    2698         with self.compute_loss_context_manager():
# -> 2699             loss = self.compute_loss(model, inputs)
#    2700
#    2701         if self.args.n_gpu > 1:
#
# /usr/local/lib/python3.9/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    2729         else:
#    2730             labels = None
# -> 2731         outputs = model(**inputs)
#    2732         # Save past state if it exists
#    2733         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1447             labels = labels.to(logits.device)
#    1448             loss_fct = CrossEntropyLoss()
# -> 1449             loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
#    1450
#    1451         if not return_dict:
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1172
#    1173     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1174         return F.cross_entropy(input, target, weight=self.weight,
#    1175                                ignore_index=self.ignore_index, reduction=self.reduction,
#    1176                                label_smoothing=self.label_smoothing)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3027     if size_average is not None or reduce is not None:
#    3028         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3029     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    3030
#    3031
#
# IndexError: Target 670 is out of bounds.

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    labels_flat = labels.flatten()
    preds_flat = preds.flatten()

    mask = labels_flat != -100  # Ignore -100 labels
    labels_flat = labels_flat[mask]
    preds_flat = preds_flat[mask]

    f1 = f1_score(labels_flat, preds_flat, average="weighted")
    return {"f1": f1}
